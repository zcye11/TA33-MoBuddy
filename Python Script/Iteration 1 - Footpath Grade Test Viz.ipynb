# %%
import pandas as pd
import geopandas as gpd

# %%
gdf = gpd.read_file('./FootpathGrades.geojson')

# %%
gdf
# Out:
#       grade1in gradepc segside statusid    asset_type deltaz streetid  \
# 0          6.5   15.44                1  Road Footway   7.08   117856
# 1          6.5   15.44             None  Road Footway   7.08     None
# 2         18.7    5.35                8  Road Footway   7.56     3098
# 3         18.7    5.35                1  Road Footway   7.56   117856
# 4          1.8   56.74                1  Road Footway   6.58   117856
# ...        ...     ...     ...      ...           ...    ...      ...
# 33267     None    None             None  Road Footway   None     None
# 33268     None    None                3  Road Footway   None   119267
# 33269     27.8     3.6             None  Road Footway    0.4     None
# 33270     None     0.0             None  Road Footway    0.0     None
# 33271     66.0    1.51             None  Road Footway   0.41     None
#
#       mccid_int   mcc_id                                            address  \
# ...

# %%
gdf.plot(figsize=(18, 18), alpha = 1)
# Out:
# <AxesSubplot:>

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 33272 entries, 0 to 33271
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grade1in    26009 non-null  object
#  1   gradepc     28839 non-null  object
#  2   segside     33272 non-null  object
#  3   statusid    20353 non-null  object
#  4   asset_type  33272 non-null  object
#  5   deltaz      28839 non-null  object
#  6   streetid    20353 non-null  object
#  7   mccid_int   20353 non-null  object
#  8   mcc_id      33272 non-null  object
#  9   address     33272 non-null  object
#  10  rlmax       28839 non-null  object
#  11  rlmin       28839 non-null  object
#  12  distance    28839 non-null  object
#  13  geometry    33272 non-null  geometry
# dtypes: geometry(1), object(13)
# memory usage: 3.6+ MB

# %%
gdf['grade1in'].head()
# Out:
# 0     6.5
# 1     6.5
# 2    18.7
# 3    18.7
# 4     1.8
# Name: grade1in, dtype: object

# %%
green = gdf[gdf.grade1in.astype('float') <= 20].assign(color='green')
yellow = gdf[(gdf.grade1in.astype('float') > 20) & (gdf.grade1in.astype('float') <= 50)].assign(color='yellow')
red = gdf[gdf.grade1in.astype('float') > 50].assign(color='red')

# %%
mel = green.append(yellow)
mel = mel.append(red)

# %%
green.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 4943 entries, 0 to 33263
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grade1in    4943 non-null   object
#  1   gradepc     4943 non-null   object
#  2   segside     4943 non-null   object
#  3   statusid    3053 non-null   object
#  4   asset_type  4943 non-null   object
#  5   deltaz      4943 non-null   object
#  6   streetid    3053 non-null   object
#  7   mccid_int   3053 non-null   object
#  8   mcc_id      4943 non-null   object
#  9   address     4943 non-null   object
#  10  rlmax       4943 non-null   object
#  11  rlmin       4943 non-null   object
#  12  distance    4943 non-null   object
#  13  geometry    4943 non-null   geometry
#  14  color       4943 non-null   object
# dtypes: geometry(1), object(14)
# memory usage: 617.9+ KB

# %%
yellow.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 10013 entries, 22 to 33269
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grade1in    10013 non-null  object
#  1   gradepc     10013 non-null  object
#  2   segside     10013 non-null  object
#  3   statusid    6123 non-null   object
#  4   asset_type  10013 non-null  object
#  5   deltaz      10013 non-null  object
#  6   streetid    6123 non-null   object
#  7   mccid_int   6123 non-null   object
#  8   mcc_id      10013 non-null  object
#  9   address     10013 non-null  object
#  10  rlmax       10013 non-null  object
#  11  rlmin       10013 non-null  object
#  12  distance    10013 non-null  object
#  13  geometry    10013 non-null  geometry
#  14  color       10013 non-null  object
# dtypes: geometry(1), object(14)
# memory usage: 1.2+ MB

# %%
red.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 11053 entries, 5 to 33271
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grade1in    11053 non-null  object
#  1   gradepc     11053 non-null  object
#  2   segside     11053 non-null  object
#  3   statusid    6485 non-null   object
#  4   asset_type  11053 non-null  object
#  5   deltaz      11053 non-null  object
#  6   streetid    6485 non-null   object
#  7   mccid_int   6485 non-null   object
#  8   mcc_id      11053 non-null  object
#  9   address     11053 non-null  object
#  10  rlmax       11053 non-null  object
#  11  rlmin       11053 non-null  object
#  12  distance    11053 non-null  object
#  13  geometry    11053 non-null  geometry
#  14  color       11053 non-null  object
# dtypes: geometry(1), object(14)
# memory usage: 1.3+ MB

# %%
mel
# Out:
#       grade1in gradepc segside statusid    asset_type deltaz streetid  \
# 0          6.5   15.44                1  Road Footway   7.08   117856
# 1          6.5   15.44             None  Road Footway   7.08     None
# 2         18.7    5.35                8  Road Footway   7.56     3098
# 3         18.7    5.35                1  Road Footway   7.56   117856
# 4          1.8   56.74                1  Road Footway   6.58   117856
# ...        ...     ...     ...      ...           ...    ...      ...
# 33253    174.3    0.57             None  Road Footway   0.63     None
# 33258     94.5    1.06             None  Road Footway   0.38     None
# 33262    358.2    0.28             None  Road Footway   0.03     None
# 33264    157.1    0.64             None  Road Footway   0.01     None
# 33271     66.0    1.51             None  Road Footway   0.41     None
#
#       mccid_int   mcc_id                          address  rlmax  rlmin  \
# ...

# %%
mel.plot(figsize=(18, 18), alpha = 1, color=mel['color'])
# Out:
# <AxesSubplot:>

# %%
mel.to_file("mel_footpath.geojson", driver='GeoJSON')
