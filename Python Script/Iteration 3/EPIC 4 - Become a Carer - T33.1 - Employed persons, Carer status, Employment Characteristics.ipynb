# %% [markdown]
# # EPIC 4 - Become a Carer - T33.1 - Employed persons, Carer status, Employment Characteristics
# This Jupyter Notebook is about preparing 'Number of primary carers, by age and sex, 2018' XLS file for being used in Mo-Buddy Website Solution.
# 1. Read Raw Data
# 2. Clean Raw Data
# 3. Export Clean Data

# %% [markdown]
# - Table_29.1 - Carer status by sex, age
# - Table_30.1 - Carer status, recipient, disability status, age, sex
# - Table_31.1 - Carer status, by geographic location, age, sex
# - Table_32.1 - 15-.. yo, carer status, sex
# - Table_33.1 - Employed 15-64 yo, carer status, sex
# - Table_34.1 - Primary Carer, recipient, age, sex
# - Table_35.1 - Carer and recipient living in or other households, age
# - Table_36.1 - Primary Carer, Time spending in care, sex  ****
# - Table_37.1 - Primary Carer, age, time spending in care, disability status, *****
# - Table_38.1 - Primary Carer, time spending in care, select recipint   ****
# - Table_39.1 - Primary Carer, reason for taking a carer, sex   ****
# - Table_40.1 - Primary Carer, reason for taking a carer, age of recipient ****
# - Table_41.1 - Primary Carer, satisfaction of service recieved, sex, age  ****
# - Table_42.1 - Primary Carer, social community participation with recipient, time spending in car, age  ****
# - Table_43.1 - Primary Carer, social community participation without recipient, time spending in car, age  ****

# %%
# Import Packages
import pandas as pd
import itertools
# import re

# %%
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Read in Raw Data from a XLS file

# %%
# Function for reading in raw data from a XLS file
def read_in_data(file_path, sheet_name):
    """
    Function for reading in raw data from XLS file.
    Inputs: 
        - file_path, type: string, desc: XLS file path
        - sheet_name, type: string, desc: Sheet Name
    Outputs:
        - raw_data, type: dataframe, desc: Raw data
    """

    raw_data = pd.read_excel(io=file_path, sheet_name=sheet_name)
    
    return raw_data

# %%
# Read in data
filepath_raw_data = 'DataBases/44300do030.xls'
sheet_name = 'Table_33.1'
df_raw_carer_33 = read_in_data(filepath_raw_data, sheet_name)

# %%
# Check how the dataframe looks like
df_raw_carer_33
# Out:
#                       Australian Bureau of Statistics     Unnamed: 1  \
# 0   44300DO030_2018 Disability, Ageing and Carers,...            NaN
# 1   Released at 11.30am (Canberra time) Thurs 24 O...            NaN
# 2   Table 33.1 Employed persons aged 15-64, living...            NaN
# 3                          Employment characteristics  Primary carer
# 4                                     ESTIMATE ('000)            NaN
# 5                              Occupation of main job            NaN
# 6                                            Managers           41.1
# 7                                       Professionals          107.6
# 8                      Technicians and Trades Workers           26.7
# 9              Community and Personal Service Workers           42.1
# 10                Clerical and Administrative Workers           63.2
# 11                                      Sales Workers           28.5
# 12                    Machinery Operators and Drivers           13.5
# 13                                          Labourers           26.8
# 14                             Inadequately described            1.2
# 15                                    All occupations          350.8
# 16                                                NaN            NaN
# 17                               Industry of main job            NaN
# 18                  Agriculture, forestry and fishing            7.5
# 19                                             Mining            1.9
# 20                                      Manufacturing           18.6
# 21         Electricity, gas, water and waste services              2
# 22                                       Construction           14.6
# 23                                    Wholesale trade            9.7
# 24                                       Retail trade           32.3
# 25                    Accommodation and food services           15.1
# 26                  Transport, postal and warehousing           14.2
# 27           Information media and telecommunications            5.1
# 28                   Financial and insurance services             10
# 29            Rental, hiring and real estate services              7
# 30    Professional, scientific and technical services           26.2
# 31                Administrative and support services             10
# 32                   Public administration and safety           32.5
# 33                             Education and training           45.7
# 34                  Health care and social assistance           79.7
# 35                       Arts and recreation services            8.1
# 36                                     Other services            9.8
# 37                             Inadequately described              0
# 38                                     All industries          350.8
# 39                                                NaN            NaN
# 40                   Sector of employment of main job            NaN
# 41                                         Government           82.5
# 42                                            Private          269.6
# 43                                          Not known              0
# 44                                                NaN            NaN
# 45                                              Total          350.8
# 46                                                NaN            NaN
# 47                                                NaN            NaN
# 48                   © Commonwealth of Australia 2019            NaN
#
#                         Unnamed: 2    Unnamed: 3   Unnamed: 4 Unnamed: 5
# 0                              NaN           NaN          NaN        NaN
# 1                              NaN           NaN          NaN        NaN
# 2                              NaN           NaN          NaN        NaN
# 3   Carer, but not a primary carer  Total carers  Not a carer      Total
# 4                              NaN           NaN          NaN        NaN
# 5                              NaN           NaN          NaN        NaN
# 6                            123.4         165.5       1345.2     1507.9
# 7                            230.4         339.8       2650.9     2992.1
# 8                            125.6         153.2         1610     1764.2
# 9                             94.8         136.8       1185.5     1322.8
# 10                           141.9         205.1       1455.8     1660.5
# 11                            78.3         106.3        970.9     1077.2
# 12                            63.3          78.2        712.6        788
# 13                            86.9           111        997.8     1112.1
# 14                             2.3           1.7         13.2       16.5
# 15                           947.4        1298.2      10943.4    12239.8
# 16                             NaN           NaN          NaN        NaN
# 17                             NaN           NaN          NaN        NaN
# 18                            24.6          31.5        217.4      250.4
# 19                            13.5            16        201.4      216.7
# 20                            62.7          81.3        781.6        862
# 21                            11.9          15.3        131.7      146.6
# 22                            73.2          88.7         1040     1130.2
# 23                              40          47.4        320.6      369.4
# 24                            93.5         124.3       1110.9     1236.2
# 25                            46.2          57.5        786.6      845.5
# 26                            58.2          70.4        560.3      631.7
# 27                            19.4          23.6        176.2      200.2
# 28                            37.6            46          416      465.2
# 29                            15.3          24.1        190.8      214.8
# 30                            70.6          96.7        911.1     1007.4
# 31                            26.4          34.3        331.2      363.6
# 32                            74.1         106.6        750.8      859.5
# 33                           107.1           152        896.5     1049.4
# 34                           124.5         202.4       1451.1       1653
# 35                            16.4          26.1        213.1      240.7
# 36                            35.6          47.6        437.9      484.1
# 37                               0           1.6         12.4         13
# 38                           947.4        1298.2      10943.4    12239.8
# 39                             NaN           NaN          NaN        NaN
# 40                             NaN           NaN          NaN        NaN
# 41                           175.5         257.3       1693.2     1951.4
# 42                             770        1036.4       9243.5    10282.3
# 43                               0             0          7.5        7.9
# 44                             NaN           NaN          NaN        NaN
# 45                           947.4        1298.2      10943.4    12239.8
# 46                             NaN           NaN          NaN        NaN
# 47                             NaN           NaN          NaN        NaN
# 48                             NaN           NaN          NaN        NaN

# %% [markdown]
# ## 2. Clean up Raw Data

# %%
# Drop useless rows and columns
col_names = df_raw_carer_33.iloc[3,:]
df_carer_33 = df_raw_carer_33.copy()
df_carer_33.drop(labels=[0,1,2, 4,5,16,17,39,40,44,46,47,48], axis=0, inplace=True)
df_carer_33.reset_index(drop=True, inplace=True)
df_carer_33.columns = col_names
df_carer_33.rename(columns={'Total':'total'}, inplace=True)
df_carer_33.columns.names = ['']
df_carer_33
# Out:
#                          Employment characteristics  Primary carer  \
# 0                        Employment characteristics  Primary carer
# 1                                          Managers           41.1
# 2                                     Professionals          107.6
# 3                    Technicians and Trades Workers           26.7
# 4            Community and Personal Service Workers           42.1
# 5               Clerical and Administrative Workers           63.2
# 6                                     Sales Workers           28.5
# 7                   Machinery Operators and Drivers           13.5
# 8                                         Labourers           26.8
# 9                            Inadequately described            1.2
# 10                                  All occupations          350.8
# 11                Agriculture, forestry and fishing            7.5
# 12                                           Mining            1.9
# 13                                    Manufacturing           18.6
# 14       Electricity, gas, water and waste services              2
# 15                                     Construction           14.6
# 16                                  Wholesale trade            9.7
# 17                                     Retail trade           32.3
# 18                  Accommodation and food services           15.1
# 19                Transport, postal and warehousing           14.2
# 20         Information media and telecommunications            5.1
# 21                 Financial and insurance services             10
# 22          Rental, hiring and real estate services              7
# 23  Professional, scientific and technical services           26.2
# 24              Administrative and support services             10
# 25                 Public administration and safety           32.5
# 26                           Education and training           45.7
# 27                Health care and social assistance           79.7
# 28                     Arts and recreation services            8.1
# 29                                   Other services            9.8
# 30                           Inadequately described              0
# 31                                   All industries          350.8
# 32                                       Government           82.5
# 33                                          Private          269.6
# 34                                        Not known              0
# 35                                            Total          350.8
#
#     Carer, but not a primary carer  Total carers  Not a carer    total
# 0   Carer, but not a primary carer  Total carers  Not a carer    Total
# 1                            123.4         165.5       1345.2   1507.9
# 2                            230.4         339.8       2650.9   2992.1
# 3                            125.6         153.2         1610   1764.2
# 4                             94.8         136.8       1185.5   1322.8
# 5                            141.9         205.1       1455.8   1660.5
# 6                             78.3         106.3        970.9   1077.2
# 7                             63.3          78.2        712.6      788
# 8                             86.9           111        997.8   1112.1
# 9                              2.3           1.7         13.2     16.5
# 10                           947.4        1298.2      10943.4  12239.8
# 11                            24.6          31.5        217.4    250.4
# 12                            13.5            16        201.4    216.7
# 13                            62.7          81.3        781.6      862
# 14                            11.9          15.3        131.7    146.6
# 15                            73.2          88.7         1040   1130.2
# 16                              40          47.4        320.6    369.4
# 17                            93.5         124.3       1110.9   1236.2
# 18                            46.2          57.5        786.6    845.5
# 19                            58.2          70.4        560.3    631.7
# 20                            19.4          23.6        176.2    200.2
# 21                            37.6            46          416    465.2
# 22                            15.3          24.1        190.8    214.8
# 23                            70.6          96.7        911.1   1007.4
# 24                            26.4          34.3        331.2    363.6
# 25                            74.1         106.6        750.8    859.5
# 26                           107.1           152        896.5   1049.4
# 27                           124.5         202.4       1451.1     1653
# 28                            16.4          26.1        213.1    240.7
# 29                            35.6          47.6        437.9    484.1
# 30                               0           1.6         12.4       13
# 31                           947.4        1298.2      10943.4  12239.8
# 32                           175.5         257.3       1693.2   1951.4
# 33                             770        1036.4       9243.5  10282.3
# 34                               0             0          7.5      7.9
# 35                           947.4        1298.2      10943.4  12239.8

# %%
# Reset index and prepare for adding multiindex (in column)
df_carer_33.rename(columns={df_carer_33.columns[0]:'Index'}, inplace=True)
df_carer_33.set_index(keys='Index', drop=True, inplace=True)
df_carer_33
# Out:
#                                                  Primary carer  \
# Index
# Employment characteristics                       Primary carer
# Managers                                                  41.1
# Professionals                                            107.6
# Technicians and Trades Workers                            26.7
# Community and Personal Service Workers                    42.1
# Clerical and Administrative Workers                       63.2
# Sales Workers                                             28.5
# Machinery Operators and Drivers                           13.5
# Labourers                                                 26.8
# Inadequately described                                     1.2
# All occupations                                          350.8
# Agriculture, forestry and fishing                          7.5
# Mining                                                     1.9
# Manufacturing                                             18.6
# Electricity, gas, water and waste services                   2
# Construction                                              14.6
# Wholesale trade                                            9.7
# Retail trade                                              32.3
# Accommodation and food services                           15.1
# Transport, postal and warehousing                         14.2
# Information media and telecommunications                   5.1
# Financial and insurance services                            10
# Rental, hiring and real estate services                      7
# Professional, scientific and technical services           26.2
# Administrative and support services                         10
# Public administration and safety                          32.5
# Education and training                                    45.7
# Health care and social assistance                         79.7
# Arts and recreation services                               8.1
# Other services                                             9.8
# Inadequately described                                       0
# All industries                                           350.8
# Government                                                82.5
# Private                                                  269.6
# Not known                                                    0
# Total                                                    350.8
#
#                                                  Carer, but not a primary carer  \
# Index
# Employment characteristics                       Carer, but not a primary carer
# Managers                                                                  123.4
# Professionals                                                             230.4
# Technicians and Trades Workers                                            125.6
# Community and Personal Service Workers                                     94.8
# Clerical and Administrative Workers                                       141.9
# Sales Workers                                                              78.3
# Machinery Operators and Drivers                                            63.3
# Labourers                                                                  86.9
# Inadequately described                                                      2.3
# All occupations                                                           947.4
# Agriculture, forestry and fishing                                          24.6
# Mining                                                                     13.5
# Manufacturing                                                              62.7
# Electricity, gas, water and waste services                                 11.9
# Construction                                                               73.2
# Wholesale trade                                                              40
# Retail trade                                                               93.5
# Accommodation and food services                                            46.2
# Transport, postal and warehousing                                          58.2
# Information media and telecommunications                                   19.4
# Financial and insurance services                                           37.6
# Rental, hiring and real estate services                                    15.3
# Professional, scientific and technical services                            70.6
# Administrative and support services                                        26.4
# Public administration and safety                                           74.1
# Education and training                                                    107.1
# Health care and social assistance                                         124.5
# Arts and recreation services                                               16.4
# Other services                                                             35.6
# Inadequately described                                                        0
# All industries                                                            947.4
# Government                                                                175.5
# Private                                                                     770
# Not known                                                                     0
# Total                                                                     947.4
#
#                                                  Total carers  Not a carer  \
# Index
# Employment characteristics                       Total carers  Not a carer
# Managers                                                165.5       1345.2
# Professionals                                           339.8       2650.9
# Technicians and Trades Workers                          153.2         1610
# Community and Personal Service Workers                  136.8       1185.5
# Clerical and Administrative Workers                     205.1       1455.8
# Sales Workers                                           106.3        970.9
# Machinery Operators and Drivers                          78.2        712.6
# Labourers                                                 111        997.8
# Inadequately described                                    1.7         13.2
# All occupations                                        1298.2      10943.4
# Agriculture, forestry and fishing                        31.5        217.4
# Mining                                                     16        201.4
# Manufacturing                                            81.3        781.6
# Electricity, gas, water and waste services               15.3        131.7
# Construction                                             88.7         1040
# Wholesale trade                                          47.4        320.6
# Retail trade                                            124.3       1110.9
# Accommodation and food services                          57.5        786.6
# Transport, postal and warehousing                        70.4        560.3
# Information media and telecommunications                 23.6        176.2
# Financial and insurance services                           46          416
# Rental, hiring and real estate services                  24.1        190.8
# Professional, scientific and technical services          96.7        911.1
# Administrative and support services                      34.3        331.2
# Public administration and safety                        106.6        750.8
# Education and training                                    152        896.5
# Health care and social assistance                       202.4       1451.1
# Arts and recreation services                             26.1        213.1
# Other services                                           47.6        437.9
# Inadequately described                                    1.6         12.4
# All industries                                         1298.2      10943.4
# Government                                              257.3       1693.2
# Private                                                1036.4       9243.5
# Not known                                                   0          7.5
# Total                                                  1298.2      10943.4
#
#                                                    total
# Index
# Employment characteristics                         Total
# Managers                                          1507.9
# Professionals                                     2992.1
# Technicians and Trades Workers                    1764.2
# Community and Personal Service Workers            1322.8
# Clerical and Administrative Workers               1660.5
# Sales Workers                                     1077.2
# Machinery Operators and Drivers                      788
# Labourers                                         1112.1
# Inadequately described                              16.5
# All occupations                                  12239.8
# Agriculture, forestry and fishing                  250.4
# Mining                                             216.7
# Manufacturing                                        862
# Electricity, gas, water and waste services         146.6
# Construction                                      1130.2
# Wholesale trade                                    369.4
# Retail trade                                      1236.2
# Accommodation and food services                    845.5
# Transport, postal and warehousing                  631.7
# Information media and telecommunications           200.2
# Financial and insurance services                   465.2
# Rental, hiring and real estate services            214.8
# Professional, scientific and technical services   1007.4
# Administrative and support services                363.6
# Public administration and safety                   859.5
# Education and training                            1049.4
# Health care and social assistance                   1653
# Arts and recreation services                       240.7
# Other services                                     484.1
# Inadequately described                                13
# All industries                                   12239.8
# Government                                        1951.4
# Private                                          10282.3
# Not known                                            7.9
# Total                                            12239.8

# %%
# Adding multiIndex (in index)
first_level = ['Carer Status', 'total']
second_level = list(col_names)[1:-1]
levels_1_1 = list(itertools.product([first_level[0]], second_level[0:4]))
levels_1_2 = list(itertools.product([first_level[1]], ['total']))
levels = levels_1_1 + levels_1_2
df_carer_33.columns = pd.MultiIndex.from_tuples(levels, names=["Carer", "Type"])
df_carer_33.reset_index(inplace=True)
df_carer_33
# Out:
# Carer                                            Index   Carer Status  \
# Type                                                    Primary carer
# 0                           Employment characteristics  Primary carer
# 1                                             Managers           41.1
# 2                                        Professionals          107.6
# 3                       Technicians and Trades Workers           26.7
# 4               Community and Personal Service Workers           42.1
# 5                  Clerical and Administrative Workers           63.2
# 6                                        Sales Workers           28.5
# 7                      Machinery Operators and Drivers           13.5
# 8                                            Labourers           26.8
# 9                               Inadequately described            1.2
# 10                                     All occupations          350.8
# 11                   Agriculture, forestry and fishing            7.5
# 12                                              Mining            1.9
# 13                                       Manufacturing           18.6
# 14          Electricity, gas, water and waste services              2
# 15                                        Construction           14.6
# 16                                     Wholesale trade            9.7
# 17                                        Retail trade           32.3
# 18                     Accommodation and food services           15.1
# 19                   Transport, postal and warehousing           14.2
# 20            Information media and telecommunications            5.1
# 21                    Financial and insurance services             10
# 22             Rental, hiring and real estate services              7
# 23     Professional, scientific and technical services           26.2
# 24                 Administrative and support services             10
# 25                    Public administration and safety           32.5
# 26                              Education and training           45.7
# 27                   Health care and social assistance           79.7
# 28                        Arts and recreation services            8.1
# 29                                      Other services            9.8
# 30                              Inadequately described              0
# 31                                      All industries          350.8
# 32                                          Government           82.5
# 33                                             Private          269.6
# 34                                           Not known              0
# 35                                               Total          350.8
#
# Carer                                                               total
# Type   Carer, but not a primary carer  Total carers  Not a carer    total
# 0      Carer, but not a primary carer  Total carers  Not a carer    Total
# 1                               123.4         165.5       1345.2   1507.9
# 2                               230.4         339.8       2650.9   2992.1
# 3                               125.6         153.2         1610   1764.2
# 4                                94.8         136.8       1185.5   1322.8
# 5                               141.9         205.1       1455.8   1660.5
# 6                                78.3         106.3        970.9   1077.2
# 7                                63.3          78.2        712.6      788
# 8                                86.9           111        997.8   1112.1
# 9                                 2.3           1.7         13.2     16.5
# 10                              947.4        1298.2      10943.4  12239.8
# 11                               24.6          31.5        217.4    250.4
# 12                               13.5            16        201.4    216.7
# 13                               62.7          81.3        781.6      862
# 14                               11.9          15.3        131.7    146.6
# 15                               73.2          88.7         1040   1130.2
# 16                                 40          47.4        320.6    369.4
# 17                               93.5         124.3       1110.9   1236.2
# 18                               46.2          57.5        786.6    845.5
# 19                               58.2          70.4        560.3    631.7
# 20                               19.4          23.6        176.2    200.2
# 21                               37.6            46          416    465.2
# 22                               15.3          24.1        190.8    214.8
# 23                               70.6          96.7        911.1   1007.4
# 24                               26.4          34.3        331.2    363.6
# 25                               74.1         106.6        750.8    859.5
# 26                              107.1           152        896.5   1049.4
# 27                              124.5         202.4       1451.1     1653
# 28                               16.4          26.1        213.1    240.7
# 29                               35.6          47.6        437.9    484.1
# 30                                  0           1.6         12.4       13
# 31                              947.4        1298.2      10943.4  12239.8
# 32                              175.5         257.3       1693.2   1951.4
# 33                                770        1036.4       9243.5  10282.3
# 34                                  0             0          7.5      7.9
# 35                              947.4        1298.2      10943.4  12239.8

# %%
# Adding multiIndex (in column)
df_carer_33.reset_index(inplace=True, drop=True)
df_carer_33
# Out:
# Carer                                            Index   Carer Status  \
# Type                                                    Primary carer
# 0                           Employment characteristics  Primary carer
# 1                                             Managers           41.1
# 2                                        Professionals          107.6
# 3                       Technicians and Trades Workers           26.7
# 4               Community and Personal Service Workers           42.1
# 5                  Clerical and Administrative Workers           63.2
# 6                                        Sales Workers           28.5
# 7                      Machinery Operators and Drivers           13.5
# 8                                            Labourers           26.8
# 9                               Inadequately described            1.2
# 10                                     All occupations          350.8
# 11                   Agriculture, forestry and fishing            7.5
# 12                                              Mining            1.9
# 13                                       Manufacturing           18.6
# 14          Electricity, gas, water and waste services              2
# 15                                        Construction           14.6
# 16                                     Wholesale trade            9.7
# 17                                        Retail trade           32.3
# 18                     Accommodation and food services           15.1
# 19                   Transport, postal and warehousing           14.2
# 20            Information media and telecommunications            5.1
# 21                    Financial and insurance services             10
# 22             Rental, hiring and real estate services              7
# 23     Professional, scientific and technical services           26.2
# 24                 Administrative and support services             10
# 25                    Public administration and safety           32.5
# 26                              Education and training           45.7
# 27                   Health care and social assistance           79.7
# 28                        Arts and recreation services            8.1
# 29                                      Other services            9.8
# 30                              Inadequately described              0
# 31                                      All industries          350.8
# 32                                          Government           82.5
# 33                                             Private          269.6
# 34                                           Not known              0
# 35                                               Total          350.8
#
# Carer                                                               total
# Type   Carer, but not a primary carer  Total carers  Not a carer    total
# 0      Carer, but not a primary carer  Total carers  Not a carer    Total
# 1                               123.4         165.5       1345.2   1507.9
# 2                               230.4         339.8       2650.9   2992.1
# 3                               125.6         153.2         1610   1764.2
# 4                                94.8         136.8       1185.5   1322.8
# 5                               141.9         205.1       1455.8   1660.5
# 6                                78.3         106.3        970.9   1077.2
# 7                                63.3          78.2        712.6      788
# 8                                86.9           111        997.8   1112.1
# 9                                 2.3           1.7         13.2     16.5
# 10                              947.4        1298.2      10943.4  12239.8
# 11                               24.6          31.5        217.4    250.4
# 12                               13.5            16        201.4    216.7
# 13                               62.7          81.3        781.6      862
# 14                               11.9          15.3        131.7    146.6
# 15                               73.2          88.7         1040   1130.2
# 16                                 40          47.4        320.6    369.4
# 17                               93.5         124.3       1110.9   1236.2
# 18                               46.2          57.5        786.6    845.5
# 19                               58.2          70.4        560.3    631.7
# 20                               19.4          23.6        176.2    200.2
# 21                               37.6            46          416    465.2
# 22                               15.3          24.1        190.8    214.8
# 23                               70.6          96.7        911.1   1007.4
# 24                               26.4          34.3        331.2    363.6
# 25                               74.1         106.6        750.8    859.5
# 26                              107.1           152        896.5   1049.4
# 27                              124.5         202.4       1451.1     1653
# 28                               16.4          26.1        213.1    240.7
# 29                               35.6          47.6        437.9    484.1
# 30                                  0           1.6         12.4       13
# 31                              947.4        1298.2      10943.4  12239.8
# 32                              175.5         257.3       1693.2   1951.4
# 33                                770        1036.4       9243.5  10282.3
# 34                                  0             0          7.5      7.9
# 35                              947.4        1298.2      10943.4  12239.8

# %%
# Dropping useless rows
df_carer_33_1 =df_carer_33.copy()
df_carer_33_1.drop(labels=[0] , axis=0, inplace=True)
df_carer_33_1.reset_index(drop=True, inplace=True)
df_carer_33_1
# Out:
# Carer                                            Index  Carer Status  \
# Type                                                   Primary carer
# 0                                             Managers          41.1
# 1                                        Professionals         107.6
# 2                       Technicians and Trades Workers          26.7
# 3               Community and Personal Service Workers          42.1
# 4                  Clerical and Administrative Workers          63.2
# 5                                        Sales Workers          28.5
# 6                      Machinery Operators and Drivers          13.5
# 7                                            Labourers          26.8
# 8                               Inadequately described           1.2
# 9                                      All occupations         350.8
# 10                   Agriculture, forestry and fishing           7.5
# 11                                              Mining           1.9
# 12                                       Manufacturing          18.6
# 13          Electricity, gas, water and waste services             2
# 14                                        Construction          14.6
# 15                                     Wholesale trade           9.7
# 16                                        Retail trade          32.3
# 17                     Accommodation and food services          15.1
# 18                   Transport, postal and warehousing          14.2
# 19            Information media and telecommunications           5.1
# 20                    Financial and insurance services            10
# 21             Rental, hiring and real estate services             7
# 22     Professional, scientific and technical services          26.2
# 23                 Administrative and support services            10
# 24                    Public administration and safety          32.5
# 25                              Education and training          45.7
# 26                   Health care and social assistance          79.7
# 27                        Arts and recreation services           8.1
# 28                                      Other services           9.8
# 29                              Inadequately described             0
# 30                                      All industries         350.8
# 31                                          Government          82.5
# 32                                             Private         269.6
# 33                                           Not known             0
# 34                                               Total         350.8
#
# Carer                                                            total
# Type  Carer, but not a primary carer Total carers Not a carer    total
# 0                              123.4        165.5      1345.2   1507.9
# 1                              230.4        339.8      2650.9   2992.1
# 2                              125.6        153.2        1610   1764.2
# 3                               94.8        136.8      1185.5   1322.8
# 4                              141.9        205.1      1455.8   1660.5
# 5                               78.3        106.3       970.9   1077.2
# 6                               63.3         78.2       712.6      788
# 7                               86.9          111       997.8   1112.1
# 8                                2.3          1.7        13.2     16.5
# 9                              947.4       1298.2     10943.4  12239.8
# 10                              24.6         31.5       217.4    250.4
# 11                              13.5           16       201.4    216.7
# 12                              62.7         81.3       781.6      862
# 13                              11.9         15.3       131.7    146.6
# 14                              73.2         88.7        1040   1130.2
# 15                                40         47.4       320.6    369.4
# 16                              93.5        124.3      1110.9   1236.2
# 17                              46.2         57.5       786.6    845.5
# 18                              58.2         70.4       560.3    631.7
# 19                              19.4         23.6       176.2    200.2
# 20                              37.6           46         416    465.2
# 21                              15.3         24.1       190.8    214.8
# 22                              70.6         96.7       911.1   1007.4
# 23                              26.4         34.3       331.2    363.6
# 24                              74.1        106.6       750.8    859.5
# 25                             107.1          152       896.5   1049.4
# 26                             124.5        202.4      1451.1     1653
# 27                              16.4         26.1       213.1    240.7
# 28                              35.6         47.6       437.9    484.1
# 29                                 0          1.6        12.4       13
# 30                             947.4       1298.2     10943.4  12239.8
# 31                             175.5        257.3      1693.2   1951.4
# 32                               770       1036.4      9243.5  10282.3
# 33                                 0            0         7.5      7.9
# 34                             947.4       1298.2     10943.4  12239.8

# %%
levels_names = list(df_carer_33_1['Index'])
levels_names
# Out:
# ['Managers',
#  'Professionals',
#  'Technicians and Trades Workers',
#  'Community and Personal Service Workers',
#  'Clerical and Administrative Workers',
#  'Sales Workers',
#  'Machinery Operators and Drivers',
#  'Labourers',
#  'Inadequately described',
#  'All occupations',
#  'Agriculture, forestry and fishing',
#  'Mining',
#  'Manufacturing',
#  'Electricity, gas, water and waste services',
#  'Construction',
#  'Wholesale trade',
#  'Retail trade',
#  'Accommodation and food services',
#  'Transport, postal and warehousing',
#  'Information media and telecommunications',
#  'Financial and insurance services',
#  'Rental, hiring and real estate services',
#  'Professional, scientific and technical services',
#  'Administrative and support services',
#  'Public administration and safety',
#  'Education and training',
#  'Health care and social assistance',
#  'Arts and recreation services',
#  'Other services',
#  'Inadequately described',
#  'All industries',
#  'Government',
#  'Private',
#  'Not known',
#  'Total']

# %%
first_level = ['Occupation on main job', 'Industry of main job', 'Sector on employment of main job']
first_level
# Out:
# ['Occupation on main job',
#  'Industry of main job',
#  'Sector on employment of main job']

# %%
second_level = levels_names
second_level
# Out:
# ['Managers',
#  'Professionals',
#  'Technicians and Trades Workers',
#  'Community and Personal Service Workers',
#  'Clerical and Administrative Workers',
#  'Sales Workers',
#  'Machinery Operators and Drivers',
#  'Labourers',
#  'Inadequately described',
#  'All occupations',
#  'Agriculture, forestry and fishing',
#  'Mining',
#  'Manufacturing',
#  'Electricity, gas, water and waste services',
#  'Construction',
#  'Wholesale trade',
#  'Retail trade',
#  'Accommodation and food services',
#  'Transport, postal and warehousing',
#  'Information media and telecommunications',
#  'Financial and insurance services',
#  'Rental, hiring and real estate services',
#  'Professional, scientific and technical services',
#  'Administrative and support services',
#  'Public administration and safety',
#  'Education and training',
#  'Health care and social assistance',
#  'Arts and recreation services',
#  'Other services',
#  'Inadequately described',
#  'All industries',
#  'Government',
#  'Private',
#  'Not known',
#  'Total']

# %%
# Adding multiIndex (in column)
first_level = ['Occupation on main job', 'Industry of main job', 'Sector on employment of main job', 'Total']
# second_level = list(col_names)[0:-1]
levels_1_1 = list(itertools.product([first_level[0]], second_level[0:10]))
levels_1_2 = list(itertools.product([first_level[1]], second_level[10:31]))
levels_1_3 = list(itertools.product([first_level[2]], second_level[31:-1]))
levels_1_4 = list(itertools.product([first_level[3]], [second_level[-1]]))
levels = levels_1_1 + levels_1_2 + levels_1_3 + levels_1_4
multi_index = pd.MultiIndex.from_tuples(levels, names=['Employment', 'Characteristics'])
df_carer_33_1.set_index(keys=multi_index, drop=True, inplace=True)
df_carer_33_1.drop(columns='Index', axis=1, inplace=True)
df_carer_33_1
# Out:
# C:\Users\Henry\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# Carer                                                                             Carer Status  \
# Type                                                                             Primary carer
# Employment                       Characteristics
# Occupation on main job           Managers                                                 41.1
#                                  Professionals                                           107.6
#                                  Technicians and Trades Workers                           26.7
#                                  Community and Personal Service Workers                   42.1
#                                  Clerical and Administrative Workers                      63.2
#                                  Sales Workers                                            28.5
#                                  Machinery Operators and Drivers                          13.5
#                                  Labourers                                                26.8
#                                  Inadequately described                                    1.2
#                                  All occupations                                         350.8
# Industry of main job             Agriculture, forestry and fishing                         7.5
#                                  Mining                                                    1.9
#                                  Manufacturing                                            18.6
#                                  Electricity, gas, water and waste services                  2
#                                  Construction                                             14.6
#                                  Wholesale trade                                           9.7
#                                  Retail trade                                             32.3
#                                  Accommodation and food services                          15.1
#                                  Transport, postal and warehousing                        14.2
#                                  Information media and telecommunications                  5.1
#                                  Financial and insurance services                           10
#                                  Rental, hiring and real estate services                     7
#                                  Professional, scientific and technical services          26.2
#                                  Administrative and support services                        10
#                                  Public administration and safety                         32.5
#                                  Education and training                                   45.7
#                                  Health care and social assistance                        79.7
#                                  Arts and recreation services                              8.1
#                                  Other services                                            9.8
#                                  Inadequately described                                      0
#                                  All industries                                          350.8
# Sector on employment of main job Government                                               82.5
#                                  Private                                                 269.6
#                                  Not known                                                   0
# Total                            Total                                                   350.8
#
# Carer                                                                                                            \
# Type                                                                             Carer, but not a primary carer
# Employment                       Characteristics
# Occupation on main job           Managers                                                                 123.4
#                                  Professionals                                                            230.4
#                                  Technicians and Trades Workers                                           125.6
#                                  Community and Personal Service Workers                                    94.8
#                                  Clerical and Administrative Workers                                      141.9
#                                  Sales Workers                                                             78.3
#                                  Machinery Operators and Drivers                                           63.3
#                                  Labourers                                                                 86.9
#                                  Inadequately described                                                     2.3
#                                  All occupations                                                          947.4
# Industry of main job             Agriculture, forestry and fishing                                         24.6
#                                  Mining                                                                    13.5
#                                  Manufacturing                                                             62.7
#                                  Electricity, gas, water and waste services                                11.9
#                                  Construction                                                              73.2
#                                  Wholesale trade                                                             40
#                                  Retail trade                                                              93.5
#                                  Accommodation and food services                                           46.2
#                                  Transport, postal and warehousing                                         58.2
#                                  Information media and telecommunications                                  19.4
#                                  Financial and insurance services                                          37.6
#                                  Rental, hiring and real estate services                                   15.3
#                                  Professional, scientific and technical services                           70.6
#                                  Administrative and support services                                       26.4
#                                  Public administration and safety                                          74.1
#                                  Education and training                                                   107.1
#                                  Health care and social assistance                                        124.5
#                                  Arts and recreation services                                              16.4
#                                  Other services                                                            35.6
#                                  Inadequately described                                                       0
#                                  All industries                                                           947.4
# Sector on employment of main job Government                                                               175.5
#                                  Private                                                                    770
#                                  Not known                                                                    0
# Total                            Total                                                                    947.4
#
# Carer                                                                                          \
# Type                                                                             Total carers
# Employment                       Characteristics
# Occupation on main job           Managers                                               165.5
#                                  Professionals                                          339.8
#                                  Technicians and Trades Workers                         153.2
#                                  Community and Personal Service Workers                 136.8
#                                  Clerical and Administrative Workers                    205.1
#                                  Sales Workers                                          106.3
#                                  Machinery Operators and Drivers                         78.2
#                                  Labourers                                                111
#                                  Inadequately described                                   1.7
#                                  All occupations                                       1298.2
# Industry of main job             Agriculture, forestry and fishing                       31.5
#                                  Mining                                                    16
#                                  Manufacturing                                           81.3
#                                  Electricity, gas, water and waste services              15.3
#                                  Construction                                            88.7
#                                  Wholesale trade                                         47.4
#                                  Retail trade                                           124.3
#                                  Accommodation and food services                         57.5
#                                  Transport, postal and warehousing                       70.4
#                                  Information media and telecommunications                23.6
#                                  Financial and insurance services                          46
#                                  Rental, hiring and real estate services                 24.1
#                                  Professional, scientific and technical services         96.7
#                                  Administrative and support services                     34.3
#                                  Public administration and safety                       106.6
#                                  Education and training                                   152
#                                  Health care and social assistance                      202.4
#                                  Arts and recreation services                            26.1
#                                  Other services                                          47.6
#                                  Inadequately described                                   1.6
#                                  All industries                                        1298.2
# Sector on employment of main job Government                                             257.3
#                                  Private                                               1036.4
#                                  Not known                                                  0
# Total                            Total                                                 1298.2
#
# Carer                                                                                         \
# Type                                                                             Not a carer
# Employment                       Characteristics
# Occupation on main job           Managers                                             1345.2
#                                  Professionals                                        2650.9
#                                  Technicians and Trades Workers                         1610
#                                  Community and Personal Service Workers               1185.5
#                                  Clerical and Administrative Workers                  1455.8
#                                  Sales Workers                                         970.9
#                                  Machinery Operators and Drivers                       712.6
#                                  Labourers                                             997.8
#                                  Inadequately described                                 13.2
#                                  All occupations                                     10943.4
# Industry of main job             Agriculture, forestry and fishing                     217.4
#                                  Mining                                                201.4
#                                  Manufacturing                                         781.6
#                                  Electricity, gas, water and waste services            131.7
#                                  Construction                                           1040
#                                  Wholesale trade                                       320.6
#                                  Retail trade                                         1110.9
#                                  Accommodation and food services                       786.6
#                                  Transport, postal and warehousing                     560.3
#                                  Information media and telecommunications              176.2
#                                  Financial and insurance services                        416
#                                  Rental, hiring and real estate services               190.8
#                                  Professional, scientific and technical services       911.1
#                                  Administrative and support services                   331.2
#                                  Public administration and safety                      750.8
#                                  Education and training                                896.5
#                                  Health care and social assistance                    1451.1
#                                  Arts and recreation services                          213.1
#                                  Other services                                        437.9
#                                  Inadequately described                                 12.4
#                                  All industries                                      10943.4
# Sector on employment of main job Government                                           1693.2
#                                  Private                                              9243.5
#                                  Not known                                               7.5
# Total                            Total                                               10943.4
#
# Carer                                                                               total
# Type                                                                                total
# Employment                       Characteristics
# Occupation on main job           Managers                                          1507.9
#                                  Professionals                                     2992.1
#                                  Technicians and Trades Workers                    1764.2
#                                  Community and Personal Service Workers            1322.8
#                                  Clerical and Administrative Workers               1660.5
#                                  Sales Workers                                     1077.2
#                                  Machinery Operators and Drivers                      788
#                                  Labourers                                         1112.1
#                                  Inadequately described                              16.5
#                                  All occupations                                  12239.8
# Industry of main job             Agriculture, forestry and fishing                  250.4
#                                  Mining                                             216.7
#                                  Manufacturing                                        862
#                                  Electricity, gas, water and waste services         146.6
#                                  Construction                                      1130.2
#                                  Wholesale trade                                    369.4
#                                  Retail trade                                      1236.2
#                                  Accommodation and food services                    845.5
#                                  Transport, postal and warehousing                  631.7
#                                  Information media and telecommunications           200.2
#                                  Financial and insurance services                   465.2
#                                  Rental, hiring and real estate services            214.8
#                                  Professional, scientific and technical services   1007.4
#                                  Administrative and support services                363.6
#                                  Public administration and safety                   859.5
#                                  Education and training                            1049.4
#                                  Health care and social assistance                   1653
#                                  Arts and recreation services                       240.7
#                                  Other services                                     484.1
#                                  Inadequately described                                13
#                                  All industries                                   12239.8
# Sector on employment of main job Government                                        1951.4
#                                  Private                                          10282.3
#                                  Not known                                            7.9
# Total                            Total                                            12239.8

# %% [markdown]
# ## 3. Export Clean Data to a CSV file

# %%
# Export full version
df_carer_33_1.to_csv('Output\EPIC4_T33_1_V1.csv', index=True)
