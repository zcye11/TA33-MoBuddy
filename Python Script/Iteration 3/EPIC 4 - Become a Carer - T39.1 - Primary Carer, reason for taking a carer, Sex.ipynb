# %% [markdown]
# # EPIC 4 - Become a Carer - T39.1 - Primary Carer, reason for taking a carer, Sex
# This Jupyter Notebook is about preparing 'Number of primary carers, by age and sex, 2018' CSV file for being used in Mo-Buddy Website Solution.
# 1. Read Raw Data
# 2. Clean Raw Data
# 3. Export Clean Data

# %% [markdown]
# - Table_29.1 - Carer status by sex, age
# - Table_30.1 - Carer status, recipient, disability status, age, sex
# - Table_31.1 - Carer status, by geographic location, age, sex
# - Table_32.1 - 15-.. yo, carer status, sex
# - Table_33.1 - Employed 15-64 yo, carer status, sex
# - Table_34.1 - Primary Carer, recipient, age, sex
# - Table_35.1 - Carer and recipient living in or other households, age
# - Table_36.1 - Primary Carer, Time spending in care, sex  ****
# - Table_37.1 - Primary Carer, age, time spending in care, disability status, *****
# - Table_38.1 - Primary Carer, time spending in care, select recipint   ****
# - Table_39.1 - Primary Carer, reason for taking a carer, sex   ****
# - Table_40.1 - Primary Carer, reason for taking a carer, age of recipient ****
# - Table_41.1 - Primary Carer, satisfaction of service recieved, sex, age  ****
# - Table_42.1 - Primary Carer, social community participation with recipient, time spending in car, age  ****
# - Table_43.1 - Primary Carer, social community participation without recipient, time spending in car, age  ****

# %%
# Import Packages
import pandas as pd
import itertools
# import re

# %%
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Read in Raw Data from a XLS file

# %%
# Function for reading in raw data from a XLS file
def read_in_data(file_path, sheet_name):
    """
    Function for reading in raw data from XLS file.
    Inputs: 
        - file_path, type: string, desc: XLS file path
        - sheet_name, type: string, desc: Sheet Name
    Outputs:
        - raw_data, type: dataframe, desc: Raw data
    """

    raw_data = pd.read_excel(io=file_path, sheet_name=sheet_name)
    
    return raw_data

# %%
# Read in data
filepath_raw_data = 'DataBases/44300do030.xls'
sheet_name = 'Table_39.1'
df_raw_carer_39 = read_in_data(filepath_raw_data, sheet_name)

# %%
# Check how the dataframe looks like
df_raw_carer_39
# Out:
#                       Australian Bureau of Statistics  \
# 0   44300DO030_2018 Disability, Ageing and Carers,...
# 1   Released at 11.30am (Canberra time) Thurs 24 O...
# 2   Table 39.1 Primary carers, reasons for taking ...
# 3                                                 NaN
# 4                                                 NaN
# 5                           PROPORTION OF PERSONS (%)
# 6                                 Male primary carers
# 7                           Could provide better care
# 8                               Family responsibility
# 9                No other family or friends available
# 10                 No other family or friends willing
# 11                               Emotional obligation
# 12                        Alternative care too costly
# 13               No other care arrangements available
# 14                                Had no other choice
# 15                                       Other reason
# 16                     Total number of persons ('000)
# 17                                                NaN
# 18                              Female primary carers
# 19                          Could provide better care
# 20                              Family responsibility
# 21               No other family or friends available
# 22                 No other family or friends willing
# 23                               Emotional obligation
# 24                        Alternative care too costly
# 25               No other care arrangements available
# 26                                Had no other choice
# 27                                       Other reason
# 28                     Total number of persons ('000)
# 29                                                NaN
# 30                                 All primary carers
# 31                          Could provide better care
# 32                              Family responsibility
# 33               No other family or friends available
# 34                 No other family or friends willing
# 35                               Emotional obligation
# 36                        Alternative care too costly
# 37               No other care arrangements available
# 38                                Had no other choice
# 39                                       Other reason
# 40                     Total number of persons ('000)
# 41                                                NaN
# 42                                                NaN
# 43                   © Commonwealth of Australia 2019
#
#                                 Unnamed: 1          Unnamed: 2  \
# 0                                      NaN                 NaN
# 1                                      NaN                 NaN
# 2                                      NaN                 NaN
# 3   Relationship to main recipient of care                 NaN
# 4                     Partner of recipient  Child of recipient
# 5                                      NaN                 NaN
# 6                                      NaN                 NaN
# 7                                     51.7                37.5
# 8                                     67.3                79.3
# 9                                     28.4                41.1
# 10                                    15.4                25.8
# 11                                    53.6                  44
# 12                                    27.7                20.2
# 13                                    16.3                15.3
# 14                                    20.5                13.2
# 15                                     8.9                 2.7
# 16                                   129.6                62.7
# 17                                     NaN                 NaN
# 18                                     NaN                 NaN
# 19                                    51.4                39.2
# 20                                      64                78.3
# 21                                      28                41.3
# 22                                    11.7                29.9
# 23                                    39.3                52.1
# 24                                    19.8                18.3
# 25                                    11.2                14.5
# 26                                    22.3                  15
# 27                                     4.1                   5
# 28                                   185.7               161.4
# 29                                     NaN                 NaN
# 30                                     NaN                 NaN
# 31                                    52.1                38.8
# 32                                    66.8                78.6
# 33                                    28.7                41.2
# 34                                    13.6                29.4
# 35                                    46.8                51.4
# 36                                    23.1                19.4
# 37                                    13.5                15.1
# 38                                    21.8                14.4
# 39                                     5.2                 4.7
# 40                                   315.2                 226
# 41                                     NaN                 NaN
# 42                                     NaN                 NaN
# 43                                     NaN                 NaN
#
#              Unnamed: 3 Unnamed: 4
# 0                   NaN        NaN
# 1                   NaN        NaN
# 2                   NaN        NaN
# 3                   NaN        NaN
# 4   Parent of recipient      Total
# 5                   NaN        NaN
# 6                   NaN        NaN
# 7                  35.5       46.4
# 8                  79.8       72.1
# 9                  13.7       31.7
# 10                 10.9         20
# 11                 29.8       48.8
# 12                   19       23.5
# 13                 13.3       17.3
# 14                 20.2       17.9
# 15                  4.4        6.4
# 16                 27.1      241.9
# 17                  NaN        NaN
# 18                  NaN        NaN
# 19                 50.6       46.5
# 20                   68       69.7
# 21                 25.4         32
# 22                   18       20.8
# 23                 46.9       45.8
# 24                 24.3       20.4
# 25                 23.8       16.4
# 26                 35.3       23.7
# 27                  9.1        6.6
# 28                205.6      618.8
# 29                  NaN        NaN
# 30                  NaN        NaN
# 31                 50.9       46.2
# 32                 71.5         70
# 33                 24.8       31.5
# 34                 17.6       20.6
# 35                 45.3       46.6
# 36                 23.3         21
# 37                   22       16.5
# 38                 34.3       21.9
# 39                  9.7        6.5
# 40                233.5      861.6
# 41                  NaN        NaN
# 42                  NaN        NaN
# 43                  NaN        NaN

# %% [markdown]
# ## 2. Clean up Raw Data

# %%
# Drop useless rows and columns
col_names = df_raw_carer_39.iloc[4,:]
df_carer_39 = df_raw_carer_39.copy()
df_carer_39.drop(labels=[0,1,2,3,5,6,16,17,18,28,29,30,40,41,42,43], axis=0, inplace=True)
df_carer_39.reset_index(drop=True, inplace=True)
df_carer_39.columns = col_names
df_carer_39.columns.names = ['']
df_carer_39
# Out:
#                                      NaN  Partner of recipient  \
# 0                                    NaN  Partner of recipient
# 1              Could provide better care                  51.7
# 2                  Family responsibility                  67.3
# 3   No other family or friends available                  28.4
# 4     No other family or friends willing                  15.4
# 5                   Emotional obligation                  53.6
# 6            Alternative care too costly                  27.7
# 7   No other care arrangements available                  16.3
# 8                    Had no other choice                  20.5
# 9                           Other reason                   8.9
# 10             Could provide better care                  51.4
# 11                 Family responsibility                    64
# 12  No other family or friends available                    28
# 13    No other family or friends willing                  11.7
# 14                  Emotional obligation                  39.3
# 15           Alternative care too costly                  19.8
# 16  No other care arrangements available                  11.2
# 17                   Had no other choice                  22.3
# 18                          Other reason                   4.1
# 19             Could provide better care                  52.1
# 20                 Family responsibility                  66.8
# 21  No other family or friends available                  28.7
# 22    No other family or friends willing                  13.6
# 23                  Emotional obligation                  46.8
# 24           Alternative care too costly                  23.1
# 25  No other care arrangements available                  13.5
# 26                   Had no other choice                  21.8
# 27                          Other reason                   5.2
#
#     Child of recipient  Parent of recipient  Total
# 0   Child of recipient  Parent of recipient  Total
# 1                 37.5                 35.5   46.4
# 2                 79.3                 79.8   72.1
# 3                 41.1                 13.7   31.7
# 4                 25.8                 10.9     20
# 5                   44                 29.8   48.8
# 6                 20.2                   19   23.5
# 7                 15.3                 13.3   17.3
# 8                 13.2                 20.2   17.9
# 9                  2.7                  4.4    6.4
# 10                39.2                 50.6   46.5
# 11                78.3                   68   69.7
# 12                41.3                 25.4     32
# 13                29.9                   18   20.8
# 14                52.1                 46.9   45.8
# 15                18.3                 24.3   20.4
# 16                14.5                 23.8   16.4
# 17                  15                 35.3   23.7
# 18                   5                  9.1    6.6
# 19                38.8                 50.9   46.2
# 20                78.6                 71.5     70
# 21                41.2                 24.8   31.5
# 22                29.4                 17.6   20.6
# 23                51.4                 45.3   46.6
# 24                19.4                 23.3     21
# 25                15.1                   22   16.5
# 26                14.4                 34.3   21.9
# 27                 4.7                  9.7    6.5

# %%
# Reset index and prepare for adding multiindex (in column)
df_carer_39.rename(columns={df_carer_39.columns[0]:'Index'}, inplace=True)
df_carer_39.set_index(keys='Index', drop=True, inplace=True)
df_carer_39
# Out:
#                                       Partner of recipient  \
# Index
# NaN                                   Partner of recipient
# Could provide better care                             51.7
# Family responsibility                                 67.3
# No other family or friends available                  28.4
# No other family or friends willing                    15.4
# Emotional obligation                                  53.6
# Alternative care too costly                           27.7
# No other care arrangements available                  16.3
# Had no other choice                                   20.5
# Other reason                                           8.9
# Could provide better care                             51.4
# Family responsibility                                   64
# No other family or friends available                    28
# No other family or friends willing                    11.7
# Emotional obligation                                  39.3
# Alternative care too costly                           19.8
# No other care arrangements available                  11.2
# Had no other choice                                   22.3
# Other reason                                           4.1
# Could provide better care                             52.1
# Family responsibility                                 66.8
# No other family or friends available                  28.7
# No other family or friends willing                    13.6
# Emotional obligation                                  46.8
# Alternative care too costly                           23.1
# No other care arrangements available                  13.5
# Had no other choice                                   21.8
# Other reason                                           5.2
#
#                                       Child of recipient  Parent of recipient  \
# Index
# NaN                                   Child of recipient  Parent of recipient
# Could provide better care                           37.5                 35.5
# Family responsibility                               79.3                 79.8
# No other family or friends available                41.1                 13.7
# No other family or friends willing                  25.8                 10.9
# Emotional obligation                                  44                 29.8
# Alternative care too costly                         20.2                   19
# No other care arrangements available                15.3                 13.3
# Had no other choice                                 13.2                 20.2
# Other reason                                         2.7                  4.4
# Could provide better care                           39.2                 50.6
# Family responsibility                               78.3                   68
# No other family or friends available                41.3                 25.4
# No other family or friends willing                  29.9                   18
# Emotional obligation                                52.1                 46.9
# Alternative care too costly                         18.3                 24.3
# No other care arrangements available                14.5                 23.8
# Had no other choice                                   15                 35.3
# Other reason                                           5                  9.1
# Could provide better care                           38.8                 50.9
# Family responsibility                               78.6                 71.5
# No other family or friends available                41.2                 24.8
# No other family or friends willing                  29.4                 17.6
# Emotional obligation                                51.4                 45.3
# Alternative care too costly                         19.4                 23.3
# No other care arrangements available                15.1                   22
# Had no other choice                                 14.4                 34.3
# Other reason                                         4.7                  9.7
#
#                                       Total
# Index
# NaN                                   Total
# Could provide better care              46.4
# Family responsibility                  72.1
# No other family or friends available   31.7
# No other family or friends willing       20
# Emotional obligation                   48.8
# Alternative care too costly            23.5
# No other care arrangements available   17.3
# Had no other choice                    17.9
# Other reason                            6.4
# Could provide better care              46.5
# Family responsibility                  69.7
# No other family or friends available     32
# No other family or friends willing     20.8
# Emotional obligation                   45.8
# Alternative care too costly            20.4
# No other care arrangements available   16.4
# Had no other choice                    23.7
# Other reason                            6.6
# Could provide better care              46.2
# Family responsibility                    70
# No other family or friends available   31.5
# No other family or friends willing     20.6
# Emotional obligation                   46.6
# Alternative care too costly              21
# No other care arrangements available   16.5
# Had no other choice                    21.9
# Other reason                            6.5

# %%
# Adding multiIndex (in column)
# first_level = ['Persons aged 0-64 years', 'Persons aged 65 years and over', 'All persons']
# second_level = ['Primary carer', 'Carer, but not a primary carer', 'Total carers', 'Not a carer', 'Total']
# levels = [first_level, second_level]
# df_carer_31.columns = pd.MultiIndex.from_product(levels, names=["Age", "Status"])
df_carer_39.reset_index(inplace=True)
df_carer_39
# Out:
#                                    Index  Partner of recipient  \
# 0                                    NaN  Partner of recipient
# 1              Could provide better care                  51.7
# 2                  Family responsibility                  67.3
# 3   No other family or friends available                  28.4
# 4     No other family or friends willing                  15.4
# 5                   Emotional obligation                  53.6
# 6            Alternative care too costly                  27.7
# 7   No other care arrangements available                  16.3
# 8                    Had no other choice                  20.5
# 9                           Other reason                   8.9
# 10             Could provide better care                  51.4
# 11                 Family responsibility                    64
# 12  No other family or friends available                    28
# 13    No other family or friends willing                  11.7
# 14                  Emotional obligation                  39.3
# 15           Alternative care too costly                  19.8
# 16  No other care arrangements available                  11.2
# 17                   Had no other choice                  22.3
# 18                          Other reason                   4.1
# 19             Could provide better care                  52.1
# 20                 Family responsibility                  66.8
# 21  No other family or friends available                  28.7
# 22    No other family or friends willing                  13.6
# 23                  Emotional obligation                  46.8
# 24           Alternative care too costly                  23.1
# 25  No other care arrangements available                  13.5
# 26                   Had no other choice                  21.8
# 27                          Other reason                   5.2
#
#     Child of recipient  Parent of recipient  Total
# 0   Child of recipient  Parent of recipient  Total
# 1                 37.5                 35.5   46.4
# 2                 79.3                 79.8   72.1
# 3                 41.1                 13.7   31.7
# 4                 25.8                 10.9     20
# 5                   44                 29.8   48.8
# 6                 20.2                   19   23.5
# 7                 15.3                 13.3   17.3
# 8                 13.2                 20.2   17.9
# 9                  2.7                  4.4    6.4
# 10                39.2                 50.6   46.5
# 11                78.3                   68   69.7
# 12                41.3                 25.4     32
# 13                29.9                   18   20.8
# 14                52.1                 46.9   45.8
# 15                18.3                 24.3   20.4
# 16                14.5                 23.8   16.4
# 17                  15                 35.3   23.7
# 18                   5                  9.1    6.6
# 19                38.8                 50.9   46.2
# 20                78.6                 71.5     70
# 21                41.2                 24.8   31.5
# 22                29.4                 17.6   20.6
# 23                51.4                 45.3   46.6
# 24                19.4                 23.3     21
# 25                15.1                   22   16.5
# 26                14.4                 34.3   21.9
# 27                 4.7                  9.7    6.5

# %%
# Dropping useless rows
df_carer_39_1 =df_carer_39.copy()
df_carer_39_1.drop(labels=[0] , axis=0, inplace=True)
df_carer_39_1.reset_index(drop=True, inplace=True)
df_carer_39_1
# Out:
#                                    Index Partner of recipient  \
# 0              Could provide better care                 51.7
# 1                  Family responsibility                 67.3
# 2   No other family or friends available                 28.4
# 3     No other family or friends willing                 15.4
# 4                   Emotional obligation                 53.6
# 5            Alternative care too costly                 27.7
# 6   No other care arrangements available                 16.3
# 7                    Had no other choice                 20.5
# 8                           Other reason                  8.9
# 9              Could provide better care                 51.4
# 10                 Family responsibility                   64
# 11  No other family or friends available                   28
# 12    No other family or friends willing                 11.7
# 13                  Emotional obligation                 39.3
# 14           Alternative care too costly                 19.8
# 15  No other care arrangements available                 11.2
# 16                   Had no other choice                 22.3
# 17                          Other reason                  4.1
# 18             Could provide better care                 52.1
# 19                 Family responsibility                 66.8
# 20  No other family or friends available                 28.7
# 21    No other family or friends willing                 13.6
# 22                  Emotional obligation                 46.8
# 23           Alternative care too costly                 23.1
# 24  No other care arrangements available                 13.5
# 25                   Had no other choice                 21.8
# 26                          Other reason                  5.2
#
#    Child of recipient Parent of recipient Total
# 0                37.5                35.5  46.4
# 1                79.3                79.8  72.1
# 2                41.1                13.7  31.7
# 3                25.8                10.9    20
# 4                  44                29.8  48.8
# 5                20.2                  19  23.5
# 6                15.3                13.3  17.3
# 7                13.2                20.2  17.9
# 8                 2.7                 4.4   6.4
# 9                39.2                50.6  46.5
# 10               78.3                  68  69.7
# 11               41.3                25.4    32
# 12               29.9                  18  20.8
# 13               52.1                46.9  45.8
# 14               18.3                24.3  20.4
# 15               14.5                23.8  16.4
# 16                 15                35.3  23.7
# 17                  5                 9.1   6.6
# 18               38.8                50.9  46.2
# 19               78.6                71.5    70
# 20               41.2                24.8  31.5
# 21               29.4                17.6  20.6
# 22               51.4                45.3  46.6
# 23               19.4                23.3    21
# 24               15.1                  22  16.5
# 25               14.4                34.3  21.9
# 26                4.7                 9.7   6.5

# %%
levels_names = df_carer_39_1['Index'].unique()
levels_names
# Out:
# array(['Could provide better care', 'Family responsibility',
#        'No other family or friends available',
#        'No other family or friends willing', 'Emotional obligation',
#        'Alternative care too costly',
#        'No other care arrangements available', 'Had no other choice',
#        'Other reason'], dtype=object)

# %%
first_level = ['Male', 'Female', 'All persons']
first_level
# Out:
# ['Male', 'Female', 'All persons']

# %%
second_level = levels_names
second_level
# Out:
# array(['Could provide better care', 'Family responsibility',
#        'No other family or friends available',
#        'No other family or friends willing', 'Emotional obligation',
#        'Alternative care too costly',
#        'No other care arrangements available', 'Had no other choice',
#        'Other reason'], dtype=object)

# %%
# Adding multiIndex (in index)
levels_all = list(itertools.product(first_level, second_level))
multi_index = pd.MultiIndex.from_tuples(levels_all, names=['Gender', 'Reason'])
df_carer_39_1.set_index(keys=multi_index, drop=True, inplace=True)
df_carer_39_1.drop(columns='Index', axis=1, inplace=True)
df_carer_39_1
# Out:
#                                                  Partner of recipient  \
# Gender      Reason
# Male        Could provide better care                            51.7
#             Family responsibility                                67.3
#             No other family or friends available                 28.4
#             No other family or friends willing                   15.4
#             Emotional obligation                                 53.6
#             Alternative care too costly                          27.7
#             No other care arrangements available                 16.3
#             Had no other choice                                  20.5
#             Other reason                                          8.9
# Female      Could provide better care                            51.4
#             Family responsibility                                  64
#             No other family or friends available                   28
#             No other family or friends willing                   11.7
#             Emotional obligation                                 39.3
#             Alternative care too costly                          19.8
#             No other care arrangements available                 11.2
#             Had no other choice                                  22.3
#             Other reason                                          4.1
# All persons Could provide better care                            52.1
#             Family responsibility                                66.8
#             No other family or friends available                 28.7
#             No other family or friends willing                   13.6
#             Emotional obligation                                 46.8
#             Alternative care too costly                          23.1
#             No other care arrangements available                 13.5
#             Had no other choice                                  21.8
#             Other reason                                          5.2
#
#                                                  Child of recipient  \
# Gender      Reason
# Male        Could provide better care                          37.5
#             Family responsibility                              79.3
#             No other family or friends available               41.1
#             No other family or friends willing                 25.8
#             Emotional obligation                                 44
#             Alternative care too costly                        20.2
#             No other care arrangements available               15.3
#             Had no other choice                                13.2
#             Other reason                                        2.7
# Female      Could provide better care                          39.2
#             Family responsibility                              78.3
#             No other family or friends available               41.3
#             No other family or friends willing                 29.9
#             Emotional obligation                               52.1
#             Alternative care too costly                        18.3
#             No other care arrangements available               14.5
#             Had no other choice                                  15
#             Other reason                                          5
# All persons Could provide better care                          38.8
#             Family responsibility                              78.6
#             No other family or friends available               41.2
#             No other family or friends willing                 29.4
#             Emotional obligation                               51.4
#             Alternative care too costly                        19.4
#             No other care arrangements available               15.1
#             Had no other choice                                14.4
#             Other reason                                        4.7
#
#                                                  Parent of recipient Total
# Gender      Reason
# Male        Could provide better care                           35.5  46.4
#             Family responsibility                               79.8  72.1
#             No other family or friends available                13.7  31.7
#             No other family or friends willing                  10.9    20
#             Emotional obligation                                29.8  48.8
#             Alternative care too costly                           19  23.5
#             No other care arrangements available                13.3  17.3
#             Had no other choice                                 20.2  17.9
#             Other reason                                         4.4   6.4
# Female      Could provide better care                           50.6  46.5
#             Family responsibility                                 68  69.7
#             No other family or friends available                25.4    32
#             No other family or friends willing                    18  20.8
#             Emotional obligation                                46.9  45.8
#             Alternative care too costly                         24.3  20.4
#             No other care arrangements available                23.8  16.4
#             Had no other choice                                 35.3  23.7
#             Other reason                                         9.1   6.6
# All persons Could provide better care                           50.9  46.2
#             Family responsibility                               71.5    70
#             No other family or friends available                24.8  31.5
#             No other family or friends willing                  17.6  20.6
#             Emotional obligation                                45.3  46.6
#             Alternative care too costly                         23.3    21
#             No other care arrangements available                  22  16.5
#             Had no other choice                                 34.3  21.9
#             Other reason                                         9.7   6.5

# %% [markdown]
# ## 3. Export Clean Data to a CSV file

# %%
# Export full version
df_carer_39_1.to_csv('Output\EPIC4_T39_1_V1.csv', index=True)
