# %% [markdown]
# # EPIC 4 - Become a Carer - T37.1 - Primary Carer, Age Carer, Time Spending, Disability Status
# This Jupyter Notebook is about preparing 'Number of primary carers, by age and sex, 2018' XLS file for being used in Mo-Buddy Website Solution.
# 1. Read Raw Data
# 2. Clean Raw Data
# 3. Export Clean Data

# %% [markdown]
# - Table_29.1 - Carer status by sex, age
# - Table_30.1 - Carer status, recipient, disability status, age, sex
# - Table_31.1 - Carer status, by geographic location, age, sex
# - Table_32.1 - 15-.. yo, carer status, sex
# - Table_33.1 - Employed 15-64 yo, carer status, sex
# - Table_34.1 - Primary Carer, recipient, age, sex
# - Table_35.1 - Carer and recipient living in or other households, age
# - Table_36.1 - Primary Carer, Time spending in care, sex  ****
# - Table_37.1 - Primary Carer, age, time spending in care, disability status, *****
# - Table_38.1 - Primary Carer, time spending in care, select recipint   ****
# - Table_39.1 - Primary Carer, reason for taking a carer, sex   ****
# - Table_40.1 - Primary Carer, reason for taking a carer, age of recipient ****
# - Table_41.1 - Primary Carer, satisfaction of service recieved, sex, age  ****
# - Table_42.1 - Primary Carer, social community participation with recipient, time spending in car, age  ****
# - Table_43.1 - Primary Carer, social community participation without recipient, time spending in car, age  ****

# %%
# Import Packages
import pandas as pd
import itertools
# import re

# %%
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Read in Raw Data from a XLS file

# %%
# Function for reading in raw data from a XLS file
def read_in_data(file_path, sheet_name):
    """
    Function for reading in raw data from XLS file.
    Inputs: 
        - file_path, type: string, desc: XLS file path
        - sheet_name, type: string, desc: Sheet Name
    Outputs:
        - raw_data, type: dataframe, desc: Raw data
    """

    raw_data = pd.read_excel(io=file_path, sheet_name=sheet_name)
    
    return raw_data

# %%
# Read in data
filepath_raw_data = 'DataBases/44300do030.xls'
sheet_name = 'Table_37.1'
df_raw_carer_37 = read_in_data(filepath_raw_data, sheet_name)

# %%
# Check how the dataframe looks like
df_raw_carer_37
# Out:
#                       Australian Bureau of Statistics  \
# 0   44300DO030_2018 Disability, Ageing and Carers,...
# 1   Released at 11.30am (Canberra time) Thurs 24 O...
# 2   Table 37.1 Primary carers, age of primary care...
# 3                                                 NaN
# 4                                                 NaN
# 5                                     ESTIMATE ('000)
# 6   Whether main recipient of care lives in same h...
# 7      Main recipient of care lives in same household
# 8                     Primary carers aged 15-44 years
# 9     Recipient has profound core activity limitation
# 10      Recipient has severe core activity limitation
# 11                       All with reported disability
# 12                                                NaN
# 13                    Primary carers aged 45-64 years
# 14    Recipient has profound core activity limitation
# 15      Recipient has severe core activity limitation
# 16                       All with reported disability
# 17                                                NaN
# 18              Primary carers aged 65 years and over
# 19    Recipient has profound core activity limitation
# 20      Recipient has severe core activity limitation
# 21                       All with reported disability
# 22                                                NaN
# 23                                 All primary carers
# 24    Recipient has profound core activity limitation
# 25      Recipient has severe core activity limitation
# 26                       All with reported disability
# 27                                                NaN
# 28             Main recipient of care lives elsewhere
# 29                                                NaN
# 30                                              Total
# 31                                                NaN
# 32                                                NaN
# 33                   © Commonwealth of Australia 2019
#
#                            Unnamed: 1   Unnamed: 2        Unnamed: 3  \
# 0                                 NaN          NaN               NaN
# 1                                 NaN          NaN               NaN
# 2                                 NaN          NaN               NaN
# 3   Average weekly hours spent caring          NaN               NaN
# 4                  Less than 20 hours  20–39 hours  40 hours or more
# 5                                 NaN          NaN               NaN
# 6                                 NaN          NaN               NaN
# 7                                 NaN          NaN               NaN
# 8                                 NaN          NaN               NaN
# 9                                  16         16.8              63.2
# 10                               42.5         14.9              22.3
# 11                               63.2         29.8                86
# 12                                NaN          NaN               NaN
# 13                                NaN          NaN               NaN
# 14                               33.6         31.3              90.8
# 15                               50.3         23.9              26.1
# 16                               91.2         55.4             124.4
# 17                                NaN          NaN               NaN
# 18                                NaN          NaN               NaN
# 19                               28.7         26.8              50.1
# 20                               38.7           17               9.1
# 21                               75.9         45.9              65.1
# 22                                NaN          NaN               NaN
# 23                                NaN          NaN               NaN
# 24                               75.9         74.4             206.8
# 25                              132.3         55.3              58.6
# 26                              233.8        134.4             274.3
# 27                                NaN          NaN               NaN
# 28                              142.2         24.6              11.2
# 29                                NaN          NaN               NaN
# 30                              376.2        158.2             286.3
# 31                                NaN          NaN               NaN
# 32                                NaN          NaN               NaN
# 33                                NaN          NaN               NaN
#
#    Unnamed: 4
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4       Total
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9          98
# 10       83.9
# 11      190.3
# 12        NaN
# 13        NaN
# 14      167.6
# 15      107.2
# 16      290.8
# 17        NaN
# 18        NaN
# 19      110.9
# 20       72.4
# 21      199.3
# 22        NaN
# 23        NaN
# 24      377.7
# 25      261.8
# 26      681.7
# 27        NaN
# 28      178.4
# 29        NaN
# 30      861.6
# 31        NaN
# 32        NaN
# 33        NaN

# %% [markdown]
# ## 2. Clean up Raw Data

# %%
# Drop useless rows and columns
col_names = df_raw_carer_37.iloc[4,:]
df_carer_37 = df_raw_carer_37.copy()
df_carer_37.drop(labels=[0,1,2,5,12,17,22,27,29,30,31,32,33], axis=0, inplace=True)
df_carer_37.reset_index(drop=True, inplace=True)
df_carer_37.columns = col_names
df_carer_37.columns.names = ['']
df_carer_37
# Out:
#                                                   NaN  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Whether main recipient of care lives in same h...
# 3      Main recipient of care lives in same household
# 4                     Primary carers aged 15-44 years
# 5     Recipient has profound core activity limitation
# 6       Recipient has severe core activity limitation
# 7                        All with reported disability
# 8                     Primary carers aged 45-64 years
# 9     Recipient has profound core activity limitation
# 10      Recipient has severe core activity limitation
# 11                       All with reported disability
# 12              Primary carers aged 65 years and over
# 13    Recipient has profound core activity limitation
# 14      Recipient has severe core activity limitation
# 15                       All with reported disability
# 16                                 All primary carers
# 17    Recipient has profound core activity limitation
# 18      Recipient has severe core activity limitation
# 19                       All with reported disability
# 20             Main recipient of care lives elsewhere
#
#                    Less than 20 hours  20–39 hours  40 hours or more  Total
# 0   Average weekly hours spent caring          NaN               NaN    NaN
# 1                  Less than 20 hours  20–39 hours  40 hours or more  Total
# 2                                 NaN          NaN               NaN    NaN
# 3                                 NaN          NaN               NaN    NaN
# 4                                 NaN          NaN               NaN    NaN
# 5                                  16         16.8              63.2     98
# 6                                42.5         14.9              22.3   83.9
# 7                                63.2         29.8                86  190.3
# 8                                 NaN          NaN               NaN    NaN
# 9                                33.6         31.3              90.8  167.6
# 10                               50.3         23.9              26.1  107.2
# 11                               91.2         55.4             124.4  290.8
# 12                                NaN          NaN               NaN    NaN
# 13                               28.7         26.8              50.1  110.9
# 14                               38.7           17               9.1   72.4
# 15                               75.9         45.9              65.1  199.3
# 16                                NaN          NaN               NaN    NaN
# 17                               75.9         74.4             206.8  377.7
# 18                              132.3         55.3              58.6  261.8
# 19                              233.8        134.4             274.3  681.7
# 20                              142.2         24.6              11.2  178.4

# %%
miss_idx = df_carer_37['Less than 20 hours'].isna()
missing_idx = df_carer_37.loc[miss_idx,:].index.values
levels_lis = list(df_carer_37.iloc[missing_idx,0])
levels_lis
# Out:
# ['Whether main recipient of care lives in same household',
#  'Main recipient of care lives in same household',
#  'Primary carers aged 15-44 years',
#  'Primary carers aged 45-64 years',
#  'Primary carers aged 65 years and over',
#  'All primary carers']

# %%
# Reset index and prepare for adding multiindex (in column)
df_carer_37.drop(labels=[0,1,2,3,4,8,12,16], axis=0, inplace=True)
df_carer_37.rename(columns={df_carer_37.columns[0]:'Index'}, inplace=True)
df_carer_37.set_index(keys='Index', drop=True, inplace=True)
df_carer_37
# Out:
#                                                 Less than 20 hours  \
# Index
# Recipient has profound core activity limitation                 16
# Recipient has severe core activity limitation                 42.5
# All with reported disability                                  63.2
# Recipient has profound core activity limitation               33.6
# Recipient has severe core activity limitation                 50.3
# All with reported disability                                  91.2
# Recipient has profound core activity limitation               28.7
# Recipient has severe core activity limitation                 38.7
# All with reported disability                                  75.9
# Recipient has profound core activity limitation               75.9
# Recipient has severe core activity limitation                132.3
# All with reported disability                                 233.8
# Main recipient of care lives elsewhere                       142.2
#
#                                                 20–39 hours 40 hours or more  \
# Index
# Recipient has profound core activity limitation        16.8             63.2
# Recipient has severe core activity limitation          14.9             22.3
# All with reported disability                           29.8               86
# Recipient has profound core activity limitation        31.3             90.8
# Recipient has severe core activity limitation          23.9             26.1
# All with reported disability                           55.4            124.4
# Recipient has profound core activity limitation        26.8             50.1
# Recipient has severe core activity limitation            17              9.1
# All with reported disability                           45.9             65.1
# Recipient has profound core activity limitation        74.4            206.8
# Recipient has severe core activity limitation          55.3             58.6
# All with reported disability                          134.4            274.3
# Main recipient of care lives elsewhere                 24.6             11.2
#
#                                                  Total
# Index
# Recipient has profound core activity limitation     98
# Recipient has severe core activity limitation     83.9
# All with reported disability                     190.3
# Recipient has profound core activity limitation  167.6
# Recipient has severe core activity limitation    107.2
# All with reported disability                     290.8
# Recipient has profound core activity limitation  110.9
# Recipient has severe core activity limitation     72.4
# All with reported disability                     199.3
# Recipient has profound core activity limitation  377.7
# Recipient has severe core activity limitation    261.8
# All with reported disability                     681.7
# Main recipient of care lives elsewhere           178.4

# %%
# Adding multiIndex (in column)
first_level = ['Average weekly hours spent caring', 'Total']
second_level = list(col_names)[1:-1]
levels_1_1 = list(itertools.product([first_level[0]], second_level[0:3]))
levels_1_2 = list(itertools.product([first_level[1]], ['Total']))
levels = levels_1_1 + levels_1_2
df_carer_37.columns = pd.MultiIndex.from_tuples(levels, names=["Type", "Time"])
df_carer_37.reset_index(inplace=True)
df_carer_37
# Out:
# Type                                            Index  \
# Time
# 0     Recipient has profound core activity limitation
# 1       Recipient has severe core activity limitation
# 2                        All with reported disability
# 3     Recipient has profound core activity limitation
# 4       Recipient has severe core activity limitation
# 5                        All with reported disability
# 6     Recipient has profound core activity limitation
# 7       Recipient has severe core activity limitation
# 8                        All with reported disability
# 9     Recipient has profound core activity limitation
# 10      Recipient has severe core activity limitation
# 11                       All with reported disability
# 12             Main recipient of care lives elsewhere
#
# Type Average weekly hours spent caring                               Total
# Time                Less than 20 hours 20–39 hours 40 hours or more  Total
# 0                                   16        16.8             63.2     98
# 1                                 42.5        14.9             22.3   83.9
# 2                                 63.2        29.8               86  190.3
# 3                                 33.6        31.3             90.8  167.6
# 4                                 50.3        23.9             26.1  107.2
# 5                                 91.2        55.4            124.4  290.8
# 6                                 28.7        26.8             50.1  110.9
# 7                                 38.7          17              9.1   72.4
# 8                                 75.9        45.9             65.1  199.3
# 9                                 75.9        74.4            206.8  377.7
# 10                               132.3        55.3             58.6  261.8
# 11                               233.8       134.4            274.3  681.7
# 12                               142.2        24.6             11.2  178.4

# %%
# Dropping useless rows
df_carer_37_1 =df_carer_37.copy()
# df_carer_36_1.drop(labels=[0] , axis=0, inplace=True)
# df_carer_36_1.reset_index(drop=True, inplace=True)
df_carer_37_1
# Out:
# Type                                            Index  \
# Time
# 0     Recipient has profound core activity limitation
# 1       Recipient has severe core activity limitation
# 2                        All with reported disability
# 3     Recipient has profound core activity limitation
# 4       Recipient has severe core activity limitation
# 5                        All with reported disability
# 6     Recipient has profound core activity limitation
# 7       Recipient has severe core activity limitation
# 8                        All with reported disability
# 9     Recipient has profound core activity limitation
# 10      Recipient has severe core activity limitation
# 11                       All with reported disability
# 12             Main recipient of care lives elsewhere
#
# Type Average weekly hours spent caring                               Total
# Time                Less than 20 hours 20–39 hours 40 hours or more  Total
# 0                                   16        16.8             63.2     98
# 1                                 42.5        14.9             22.3   83.9
# 2                                 63.2        29.8               86  190.3
# 3                                 33.6        31.3             90.8  167.6
# 4                                 50.3        23.9             26.1  107.2
# 5                                 91.2        55.4            124.4  290.8
# 6                                 28.7        26.8             50.1  110.9
# 7                                 38.7          17              9.1   72.4
# 8                                 75.9        45.9             65.1  199.3
# 9                                 75.9        74.4            206.8  377.7
# 10                               132.3        55.3             58.6  261.8
# 11                               233.8       134.4            274.3  681.7
# 12                               142.2        24.6             11.2  178.4

# %%
levels_names = df_carer_37_1['Index'].unique()
levels_names
# Out:
# array(['Recipient has profound core activity limitation',
#        'Recipient has severe core activity limitation',
#        'All with reported disability',
#        'Main recipient of care lives elsewhere'], dtype=object)

# %%
first_level = [levels_lis[1] ,levels_names[-1]]
first_level
# Out:
# ['Main recipient of care lives in same household',
#  'Main recipient of care lives elsewhere']

# %%
second_level = levels_lis[2:]
second_level
# Out:
# ['Primary carers aged 15-44 years',
#  'Primary carers aged 45-64 years',
#  'Primary carers aged 65 years and over',
#  'All primary carers']

# %%
third_level = list(levels_names[0:-1])
third_level
# Out:
# ['Recipient has profound core activity limitation',
#  'Recipient has severe core activity limitation',
#  'All with reported disability']

# %%
# Adding multiIndex (in index)
levels_1 = list(itertools.product([first_level[0]],second_level, third_level))
levels_2 = list(itertools.product([first_level[1]],[second_level[3]], [first_level[1]]))
levels_all = levels_1 + levels_2
multi_index = pd.MultiIndex.from_tuples(levels_all, names=['Place', 'Age', 'Disability Status'])
df_carer_37_1.set_index(keys=multi_index, drop=True, inplace=True)
df_carer_37_1.drop(columns='Index', axis=1, inplace=True)
df_carer_37_1
# Out:
# C:\Users\Henry\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# Type                                                                                                                                 Average weekly hours spent caring  \
# Time                                                                                                                                                Less than 20 hours
# Place                                          Age                                   Disability Status
# Main recipient of care lives in same household Primary carers aged 15-44 years       Recipient has profound core activity limitation                                16
#                                                                                      Recipient has severe core activity limitation                                42.5
#                                                                                      All with reported disability                                                 63.2
#                                                Primary carers aged 45-64 years       Recipient has profound core activity limitation                              33.6
#                                                                                      Recipient has severe core activity limitation                                50.3
#                                                                                      All with reported disability                                                 91.2
#                                                Primary carers aged 65 years and over Recipient has profound core activity limitation                              28.7
#                                                                                      Recipient has severe core activity limitation                                38.7
#                                                                                      All with reported disability                                                 75.9
#                                                All primary carers                    Recipient has profound core activity limitation                              75.9
#                                                                                      Recipient has severe core activity limitation                               132.3
#                                                                                      All with reported disability                                                233.8
# Main recipient of care lives elsewhere         All primary carers                    Main recipient of care lives elsewhere                                      142.2
#
# Type                                                                                                                                              \
# Time                                                                                                                                 20–39 hours
# Place                                          Age                                   Disability Status
# Main recipient of care lives in same household Primary carers aged 15-44 years       Recipient has profound core activity limitation        16.8
#                                                                                      Recipient has severe core activity limitation          14.9
#                                                                                      All with reported disability                           29.8
#                                                Primary carers aged 45-64 years       Recipient has profound core activity limitation        31.3
#                                                                                      Recipient has severe core activity limitation          23.9
#                                                                                      All with reported disability                           55.4
#                                                Primary carers aged 65 years and over Recipient has profound core activity limitation        26.8
#                                                                                      Recipient has severe core activity limitation            17
#                                                                                      All with reported disability                           45.9
#                                                All primary carers                    Recipient has profound core activity limitation        74.4
#                                                                                      Recipient has severe core activity limitation          55.3
#                                                                                      All with reported disability                          134.4
# Main recipient of care lives elsewhere         All primary carers                    Main recipient of care lives elsewhere                 24.6
#
# Type                                                                                                                                                   \
# Time                                                                                                                                 40 hours or more
# Place                                          Age                                   Disability Status
# Main recipient of care lives in same household Primary carers aged 15-44 years       Recipient has profound core activity limitation             63.2
#                                                                                      Recipient has severe core activity limitation               22.3
#                                                                                      All with reported disability                                  86
#                                                Primary carers aged 45-64 years       Recipient has profound core activity limitation             90.8
#                                                                                      Recipient has severe core activity limitation               26.1
#                                                                                      All with reported disability                               124.4
#                                                Primary carers aged 65 years and over Recipient has profound core activity limitation             50.1
#                                                                                      Recipient has severe core activity limitation                9.1
#                                                                                      All with reported disability                                65.1
#                                                All primary carers                    Recipient has profound core activity limitation            206.8
#                                                                                      Recipient has severe core activity limitation               58.6
#                                                                                      All with reported disability                               274.3
# Main recipient of care lives elsewhere         All primary carers                    Main recipient of care lives elsewhere                      11.2
#
# Type                                                                                                                                  Total
# Time                                                                                                                                  Total
# Place                                          Age                                   Disability Status
# Main recipient of care lives in same household Primary carers aged 15-44 years       Recipient has profound core activity limitation     98
#                                                                                      Recipient has severe core activity limitation     83.9
#                                                                                      All with reported disability                     190.3
#                                                Primary carers aged 45-64 years       Recipient has profound core activity limitation  167.6
#                                                                                      Recipient has severe core activity limitation    107.2
#                                                                                      All with reported disability                     290.8
#                                                Primary carers aged 65 years and over Recipient has profound core activity limitation  110.9
#                                                                                      Recipient has severe core activity limitation     72.4
#                                                                                      All with reported disability                     199.3
#                                                All primary carers                    Recipient has profound core activity limitation  377.7
#                                                                                      Recipient has severe core activity limitation    261.8
#                                                                                      All with reported disability                     681.7
# Main recipient of care lives elsewhere         All primary carers                    Main recipient of care lives elsewhere           178.4

# %% [markdown]
# ## 3. Export Clean Data to a CSV file

# %%
# Export full version
df_carer_37_1.to_csv('Output\EPIC4_T37_1_V1.csv', index=True)
