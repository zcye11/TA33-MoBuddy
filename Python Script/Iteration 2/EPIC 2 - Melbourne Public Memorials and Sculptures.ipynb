# %% [markdown]
# # EPIC 2 - Melbourne Public Memorials and Sculptures
# This Jupyter Notebook is about preparing 'Melbourne Public Memorials and Sculptures' CSV file for being used in Mo-Buddy Website Solution.
# 1. Read Raw Data
# 2. Clean Raw Data
# 3. Export Clean Data

# %%
# Import Packages
import pandas as pd

# %%
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Read in Raw Data from a CSV file

# %%
# Function for reading in raw data from a CSV file
def read_in_data(file_path):
    """
    Function for reading in raw data from CSV file.
    Inputs: 
        - file_Path, type: string, desc: CSV file path
    Outputs:
        - raw_data, type: dataframe, desc: Raw data
    """

    raw_data = pd.read_csv(file_path)
    
    return raw_data

# %%
# Read in data
filepath_raw_data = 'DataBases\Public_memorials_and_sculptures.csv'
df_raw_monuments = read_in_data(filepath_raw_data)

# %%
df_raw_monuments.head()
# Out:
#                                          Description  \
# 0            Arts & Heritage  - Memorials - Fountain
# 1  Arts & Heritage  - Sculpture - Memorial Sculpture
# 2           Arts & Heritage  - Memorials - Sculpture
# 3            Arts & Heritage  - Sculpture - Memorial
# 4              Arts & Heritage  - Sculpture - Paving
#
#                                                Title  \
# 0                                     Coles Fountain
# 1  South African War Memorial (Memorial to Fallen...
# 2                               World War 1 Memorial
# 3                          Sir Edward "Weary" Dunlop
# 4                                         Zoo Paving
#
#                             Co-ordinates
# 0  (-37.8097706399894, 144.973483970263)
# 1   (-37.8259414540802, 144.97185679034)
# 2  (-37.7915502247943, 144.958086476511)
# 3  (-37.8253098033481, 144.971594258329)
# 4   (-37.782561322013, 144.953293930765)

# %% [markdown]
# ## 2. Clean up Raw Data

# %%
# Check missing values
df_raw_monuments.isnull().sum()
# Out:
# Description     0
# Title           0
# Co-ordinates    0
# dtype: int64

# %%
df_monuments = df_raw_monuments.copy()

# %%
# Split 'Description' -> 'Type1', 'Type2', 'Type3'
description_split = df_monuments['Description'].str.split(' - ')
df_monuments.insert(1, 'class', description_split.str[0])
df_monuments.insert(2, 'kind', description_split.str[1:])
# df_monuments.insert(3, 'type', description_split.str[2])

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#                                          Description             class  \
# 0            Arts & Heritage  - Memorials - Fountain  Arts & Heritage
# 1  Arts & Heritage  - Sculpture - Memorial Sculpture  Arts & Heritage
# 2           Arts & Heritage  - Memorials - Sculpture  Arts & Heritage
# 3            Arts & Heritage  - Sculpture - Memorial  Arts & Heritage
# 4              Arts & Heritage  - Sculpture - Paving  Arts & Heritage
#
#                               kind  \
# 0            [Memorials, Fountain]
# 1  [Sculpture, Memorial Sculpture]
# 2           [Memorials, Sculpture]
# 3            [Sculpture, Memorial]
# 4              [Sculpture, Paving]
#
#                                                Title  \
# 0                                     Coles Fountain
# 1  South African War Memorial (Memorial to Fallen...
# 2                               World War 1 Memorial
# 3                          Sir Edward "Weary" Dunlop
# 4                                         Zoo Paving
#
#                             Co-ordinates
# 0  (-37.8097706399894, 144.973483970263)
# 1   (-37.8259414540802, 144.97185679034)
# 2  (-37.7915502247943, 144.958086476511)
# 3  (-37.8253098033481, 144.971594258329)
# 4   (-37.782561322013, 144.953293930765)

# %%
# Check missing values
df_monuments.isnull().sum()
# Out:
# Description     0
# class           0
# kind            0
# Title           0
# Co-ordinates    0
# dtype: int64

# %%
# Check monument according to 'class'
df_monuments['class'].value_counts()
# Out:
# Arts & Heritage                152
# Art and Heritage Collection      4
# Art & Heritage Collection        2
# Art & Heritage                   2
# Art and Heritage                 1
# Art & Heritage Collection -      1
# Arts & Heritage                  1
# Name: class, dtype: int64

# %%
df_monuments.loc[:,'class'] = 'Art and Heritage'
df_monuments['class'].value_counts()
# Out:
# Art and Heritage    163
# Name: class, dtype: int64

# %%
df_monuments['kind_'] = df_monuments['kind'].apply(lambda x: ', '.join(sorted(list(set(x))))) #', '.join(x))

# %%
df_monuments
# Out:
#                                            Description             class  \
# 0              Arts & Heritage  - Memorials - Fountain  Art and Heritage
# 1    Arts & Heritage  - Sculpture - Memorial Sculpture  Art and Heritage
# 2             Arts & Heritage  - Memorials - Sculpture  Art and Heritage
# 3              Arts & Heritage  - Sculpture - Memorial  Art and Heritage
# 4                Arts & Heritage  - Sculpture - Paving  Art and Heritage
# ..                                                 ...               ...
# 158  Art and Heritage - Sculpture - Commonwealth Ga...  Art and Heritage
# 159           Arts & Heritage  - Sculpture - Sculpture  Art and Heritage
# 160   Arts & Heritage  - Memorials - Drinking Fountain  Art and Heritage
# 161            Arts & Heritage  - Sculpture - Memorial  Art and Heritage
# 162               Arts & Heritage  - Sculpture - Model  Art and Heritage
#
#                                     kind  \
# 0                  [Memorials, Fountain]
# 1        [Sculpture, Memorial Sculpture]
# 2                 [Memorials, Sculpture]
# 3                  [Sculpture, Memorial]
# 4                    [Sculpture, Paving]
# ..                                   ...
# 158  [Sculpture, Commonwealth Games Eel]
# 159               [Sculpture, Sculpture]
# 160       [Memorials, Drinking Fountain]
# 161                [Sculpture, Memorial]
# 162                   [Sculpture, Model]
#
#                                                  Title  \
# 0                                       Coles Fountain
# 1    South African War Memorial (Memorial to Fallen...
# 2                                 World War 1 Memorial
# 3                            Sir Edward "Weary" Dunlop
# 4                                           Zoo Paving
# ..                                                 ...
# 158       Commonwealth Games Aquatic Sculptures - Eels
# 159                       Australia Today and Tomorrow
# 160                 Stapley Memorial Drinking Fountain
# 161                                   Tilly Aston Bell
# 162                                Model Tudor Village
#
#                               Co-ordinates                              kind_
# 0    (-37.8097706399894, 144.973483970263)                Fountain, Memorials
# 1     (-37.8259414540802, 144.97185679034)      Memorial Sculpture, Sculpture
# 2    (-37.7915502247943, 144.958086476511)               Memorials, Sculpture
# 3    (-37.8253098033481, 144.971594258329)                Memorial, Sculpture
# 4     (-37.782561322013, 144.953293930765)                  Paving, Sculpture
# ..                                     ...                                ...
# 158  (-37.7966290758514, 144.924306747344)  Commonwealth Games Eel, Sculpture
# 159  (-37.8140548926813, 144.967338697856)                          Sculpture
# 160  (-37.8189109755954, 144.973021226526)       Drinking Fountain, Memorials
# 161  (-37.8253717421153, 144.975900160659)                Memorial, Sculpture
# 162  (-37.8132572127115, 144.981012344621)                   Model, Sculpture
#
# [163 rows x 6 columns]

# %%
# Check monument according to 'class'
df_monuments['kind_'].value_counts()
# Out:
# Sculpture                                                       62
# Drinking Fountain, Memorials                                    18
# Fountain, Sculpture                                             10
# Memorial, Sculpture                                             10
# Fountain, Memorials                                              5
# Monument, Sculpture                                              4
# Memorials, Waterfall                                             3
# Pavement inlay, Sculpture                                        3
# Memorial, Memorials                                              3
# Sculpture, Statue                                                3
# Bust, Sculpture                                                  3
# Memorial Sculpture, Sculpture                                    2
# Sculpture, Sculpture / Seat                                      2
# Rotunda, Sculpture                                               2
# Mural, Sculpture                                                 2
# Memorial Drinking Fountain, Memorials                            2
# Cairn, Sculpture                                                 2
# Hitching Post, Sculpture                                         1
# Indigenous                                                       1
# Bricks / Tiles, Sculpture                                        1
# Aurora Sculpture, Sculpture in Docklands                         1
# Garden/Sculpture, Memorials                                      1
# Memorials, Sculpture                                             1
# 'Maxims of Behaviour", Artwork Commission, Bourke Street         1
# Paving, Sculpture                                                1
# Model, Sculpture                                                 1
# Fountain                                                         1
#                                                                  1
# Pastor Sir Doug Nicholls and Lady Gladys Nicholls, Sculpture     1
# Cenotaph, Memorials                                              1
# Arts Victoria, Federation Bells                                  1
# Memorial statue, Sculpture                                       1
# Memorial                                                         1
# Unknown                                                          1
# Sculpture, Window                                                1
# Bandstand, Sculpture                                             1
# Horology, Sundial                                                1
# Fruition, Sculpture                                              1
# Commonwealth Games Eel, Sculpture                                1
# Sculpture, Waterfall                                             1
# Sculpture, Speakers Corner                                       1
# Sculpture, Sculpture- Common Ground BMarr (AW5003)               1
# Cow Up a Tree, Docklands Sculpture, Sculpture                    1
# Raising the Rattler Pole, Sculpture                              1
# Name: kind_, dtype: int64

# %%
# Check missing values
df_monuments[df_monuments['kind_']=='']
# Out:
#                     Description             class kind           Title  \
# 98  Art & Heritage Collection -  Art and Heritage   []  Great Petition
#
#                             Co-ordinates kind_
# 98  (-37.811529640687, 144.975170291578)

# %%
df_monuments.loc[df_monuments['Title']=='Great Petition','kind_'] = 'Sculpture'

# Check missing values
df_monuments[df_monuments['kind_']=='']
# Out:
# Empty DataFrame
# Columns: [Description, class, kind, Title, Co-ordinates, kind_]
# Index: []

# %%
df_monuments.loc[df_monuments['Title']=='Maxims of Behaviour','kind_'] = 'Artwork'
df_monuments.loc[df_monuments['Title']=='Pastor Sir Doug Nicholls and Lady Gladys Nicholls','kind_'] = 'Sculpture'
df_monuments.loc[df_monuments['Title']=='Commonwealth Games Aquatic Sculptures - Eels','kind_'] = 'Sculpture'
df_monuments.loc[df_monuments['Title']=='Birrarung Wilam [Common Ground]','kind_'] = 'Sculpture'
df_monuments.loc[df_monuments['Title']=='Cow Up A Tree','kind_'] = 'Sculpture'
df_monuments.loc[df_monuments['Title']=='Raising the Rattler Pole','kind_'] = 'Sculpture'

# %%
# Check monument according to 'type'
df_monuments['kind_'].value_counts()
# Out:
# Sculpture                                   68
# Drinking Fountain, Memorials                18
# Fountain, Sculpture                         10
# Memorial, Sculpture                         10
# Fountain, Memorials                          5
# Monument, Sculpture                          4
# Sculpture, Statue                            3
# Bust, Sculpture                              3
# Pavement inlay, Sculpture                    3
# Memorials, Waterfall                         3
# Memorial, Memorials                          3
# Rotunda, Sculpture                           2
# Mural, Sculpture                             2
# Sculpture, Sculpture / Seat                  2
# Memorial Drinking Fountain, Memorials        2
# Cairn, Sculpture                             2
# Memorial Sculpture, Sculpture                2
# Indigenous                                   1
# Garden/Sculpture, Memorials                  1
# Memorials, Sculpture                         1
# Bricks / Tiles, Sculpture                    1
# Aurora Sculpture, Sculpture in Docklands     1
# Paving, Sculpture                            1
# Model, Sculpture                             1
# Hitching Post, Sculpture                     1
# Unknown                                      1
# Cenotaph, Memorials                          1
# Arts Victoria, Federation Bells              1
# Memorial statue, Sculpture                   1
# Memorial                                     1
# Sculpture, Speakers Corner                   1
# Sculpture, Window                            1
# Bandstand, Sculpture                         1
# Fruition, Sculpture                          1
# Artwork                                      1
# Sculpture, Waterfall                         1
# Horology, Sundial                            1
# Fountain                                     1
# Name: kind_, dtype: int64

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#                                          Description             class  \
# 0            Arts & Heritage  - Memorials - Fountain  Art and Heritage
# 1  Arts & Heritage  - Sculpture - Memorial Sculpture  Art and Heritage
# 2           Arts & Heritage  - Memorials - Sculpture  Art and Heritage
# 3            Arts & Heritage  - Sculpture - Memorial  Art and Heritage
# 4              Arts & Heritage  - Sculpture - Paving  Art and Heritage
#
#                               kind  \
# 0            [Memorials, Fountain]
# 1  [Sculpture, Memorial Sculpture]
# 2           [Memorials, Sculpture]
# 3            [Sculpture, Memorial]
# 4              [Sculpture, Paving]
#
#                                                Title  \
# 0                                     Coles Fountain
# 1  South African War Memorial (Memorial to Fallen...
# 2                               World War 1 Memorial
# 3                          Sir Edward "Weary" Dunlop
# 4                                         Zoo Paving
#
#                             Co-ordinates                          kind_
# 0  (-37.8097706399894, 144.973483970263)            Fountain, Memorials
# 1   (-37.8259414540802, 144.97185679034)  Memorial Sculpture, Sculpture
# 2  (-37.7915502247943, 144.958086476511)           Memorials, Sculpture
# 3  (-37.8253098033481, 144.971594258329)            Memorial, Sculpture
# 4   (-37.782561322013, 144.953293930765)              Paving, Sculpture

# %%
# split 'Co-ordinates' -> 'latitude' 'longitude'
long_lati = df_monuments['Co-ordinates'].str.extract(r'\((.*)\)')[0].str.split(', ')
df_monuments.insert(6, 'latitude', long_lati.str[0])
df_monuments.insert(7, 'longitude', long_lati.str[1])

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#                                          Description             class  \
# 0            Arts & Heritage  - Memorials - Fountain  Art and Heritage
# 1  Arts & Heritage  - Sculpture - Memorial Sculpture  Art and Heritage
# 2           Arts & Heritage  - Memorials - Sculpture  Art and Heritage
# 3            Arts & Heritage  - Sculpture - Memorial  Art and Heritage
# 4              Arts & Heritage  - Sculpture - Paving  Art and Heritage
#
#                               kind  \
# 0            [Memorials, Fountain]
# 1  [Sculpture, Memorial Sculpture]
# 2           [Memorials, Sculpture]
# 3            [Sculpture, Memorial]
# 4              [Sculpture, Paving]
#
#                                                Title  \
# 0                                     Coles Fountain
# 1  South African War Memorial (Memorial to Fallen...
# 2                               World War 1 Memorial
# 3                          Sir Edward "Weary" Dunlop
# 4                                         Zoo Paving
#
#                             Co-ordinates                          kind_  \
# 0  (-37.8097706399894, 144.973483970263)            Fountain, Memorials
# 1   (-37.8259414540802, 144.97185679034)  Memorial Sculpture, Sculpture
# 2  (-37.7915502247943, 144.958086476511)           Memorials, Sculpture
# 3  (-37.8253098033481, 144.971594258329)            Memorial, Sculpture
# 4   (-37.782561322013, 144.953293930765)              Paving, Sculpture
#
#             latitude         longitude
# 0  -37.8097706399894  144.973483970263
# 1  -37.8259414540802   144.97185679034
# 2  -37.7915502247943  144.958086476511
# 3  -37.8253098033481  144.971594258329
# 4   -37.782561322013  144.953293930765

# %%
# Selet only usefull columns
useful_column = ['class', 'kind_', 'Title', 'latitude', 'longitude']
df_monuments = df_monuments.loc[:,useful_column]

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#               class                          kind_  \
# 0  Art and Heritage            Fountain, Memorials
# 1  Art and Heritage  Memorial Sculpture, Sculpture
# 2  Art and Heritage           Memorials, Sculpture
# 3  Art and Heritage            Memorial, Sculpture
# 4  Art and Heritage              Paving, Sculpture
#
#                                                Title           latitude  \
# 0                                     Coles Fountain  -37.8097706399894
# 1  South African War Memorial (Memorial to Fallen...  -37.8259414540802
# 2                               World War 1 Memorial  -37.7915502247943
# 3                          Sir Edward "Weary" Dunlop  -37.8253098033481
# 4                                         Zoo Paving   -37.782561322013
#
#           longitude
# 0  144.973483970263
# 1   144.97185679034
# 2  144.958086476511
# 3  144.971594258329
# 4  144.953293930765

# %%
# Rename columns accordingly with format
df_monuments.rename(columns={'Title':'title', 'kind_':'kind'}, inplace=True)

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#               class                           kind  \
# 0  Art and Heritage            Fountain, Memorials
# 1  Art and Heritage  Memorial Sculpture, Sculpture
# 2  Art and Heritage           Memorials, Sculpture
# 3  Art and Heritage            Memorial, Sculpture
# 4  Art and Heritage              Paving, Sculpture
#
#                                                title           latitude  \
# 0                                     Coles Fountain  -37.8097706399894
# 1  South African War Memorial (Memorial to Fallen...  -37.8259414540802
# 2                               World War 1 Memorial  -37.7915502247943
# 3                          Sir Edward "Weary" Dunlop  -37.8253098033481
# 4                                         Zoo Paving   -37.782561322013
#
#           longitude
# 0  144.973483970263
# 1   144.97185679034
# 2  144.958086476511
# 3  144.971594258329
# 4  144.953293930765

# %%
# Include monument id (created)
df_monuments.insert(0, 'id', 'MON-')
df_monuments.insert(1, 'id_', range(1,len(df_monuments)+1))

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#      id  id_             class                           kind  \
# 0  MON-    1  Art and Heritage            Fountain, Memorials
# 1  MON-    2  Art and Heritage  Memorial Sculpture, Sculpture
# 2  MON-    3  Art and Heritage           Memorials, Sculpture
# 3  MON-    4  Art and Heritage            Memorial, Sculpture
# 4  MON-    5  Art and Heritage              Paving, Sculpture
#
#                                                title           latitude  \
# 0                                     Coles Fountain  -37.8097706399894
# 1  South African War Memorial (Memorial to Fallen...  -37.8259414540802
# 2                               World War 1 Memorial  -37.7915502247943
# 3                          Sir Edward "Weary" Dunlop  -37.8253098033481
# 4                                         Zoo Paving   -37.782561322013
#
#           longitude
# 0  144.973483970263
# 1   144.97185679034
# 2  144.958086476511
# 3  144.971594258329
# 4  144.953293930765

# %%
# Include monument id (created)
df_monuments = df_monuments.astype({'id_':str})
df_monuments['id'] = df_monuments['id'] + df_monuments['id_']

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#       id id_             class                           kind  \
# 0  MON-1   1  Art and Heritage            Fountain, Memorials
# 1  MON-2   2  Art and Heritage  Memorial Sculpture, Sculpture
# 2  MON-3   3  Art and Heritage           Memorials, Sculpture
# 3  MON-4   4  Art and Heritage            Memorial, Sculpture
# 4  MON-5   5  Art and Heritage              Paving, Sculpture
#
#                                                title           latitude  \
# 0                                     Coles Fountain  -37.8097706399894
# 1  South African War Memorial (Memorial to Fallen...  -37.8259414540802
# 2                               World War 1 Memorial  -37.7915502247943
# 3                          Sir Edward "Weary" Dunlop  -37.8253098033481
# 4                                         Zoo Paving   -37.782561322013
#
#           longitude
# 0  144.973483970263
# 1   144.97185679034
# 2  144.958086476511
# 3  144.971594258329
# 4  144.953293930765

# %%
# Selet only usefull columns
useful_column = ['id', 'class', 'kind', 'title', 'latitude', 'longitude']
df_monuments = df_monuments.loc[:,useful_column]

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#       id             class                           kind  \
# 0  MON-1  Art and Heritage            Fountain, Memorials
# 1  MON-2  Art and Heritage  Memorial Sculpture, Sculpture
# 2  MON-3  Art and Heritage           Memorials, Sculpture
# 3  MON-4  Art and Heritage            Memorial, Sculpture
# 4  MON-5  Art and Heritage              Paving, Sculpture
#
#                                                title           latitude  \
# 0                                     Coles Fountain  -37.8097706399894
# 1  South African War Memorial (Memorial to Fallen...  -37.8259414540802
# 2                               World War 1 Memorial  -37.7915502247943
# 3                          Sir Edward "Weary" Dunlop  -37.8253098033481
# 4                                         Zoo Paving   -37.782561322013
#
#           longitude
# 0  144.973483970263
# 1   144.97185679034
# 2  144.958086476511
# 3  144.971594258329
# 4  144.953293930765

# %% [markdown]
# ## 3. Export Clean Data to a CSV file

# %%
# Export full version
df_monuments.to_csv('Output\Monuments\OK_Public_Monuments_Melbourne_V3.csv', index=False)
