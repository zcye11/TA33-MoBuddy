# %% [markdown]
# # EPIC 2 - Melbourne Public Artworks, Fountain, Monuments
# This Jupyter Notebook is about preparing 'Public Public Artworks, Fountain, Monuments' CSV file for being used in Mo-Buddy Website Solution.
# 1. Read Raw Data
# 2. Clean Raw Data
# 3. Export Clean Data

# %%
# Import Packages
import pandas as pd

# %%
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Read in Raw Data from a CSV file

# %%
# Function for reading in raw data from a CSV file
def read_in_data(file_path):
    """
    Function for reading in raw data from CSV file.
    Inputs: 
        - file_Path, type: string, desc: CSV file path
    Outputs:
        - raw_data, type: dataframe, desc: Raw data
    """

    raw_data = pd.read_csv(file_path)
    
    return raw_data

# %%
# Read in data
filepath_raw_data = 'DataBases\Public_artworks__fountains_and_monuments.csv'
df_raw_monuments = read_in_data(filepath_raw_data)

# %%
df_raw_monuments.head()
# Out:
#   Asset Type                                   Name  \
# 0   Fountain                         Coles Fountain
# 1        Art                  Port Phillip Monument
# 2   Monument  Black Swan Memorial Drinking Fountain
# 3        Art                               Blowhole
# 4        Art                            Bird Panels
#
#                            Xorg                               Xsource  \
# 0             City of Melbourne  MCC - Ortho Image March 2005 - Final
# 1             City of Melbourne  MCC - Ortho Image March 2005 - Final
# 2             City of Melbourne  MCC - Ortho Image March 2005 - Final
# 3  Beveridge Williams Surveyors                          Field Survey
# 4             City of Melbourne  MCC - Ortho Image March 2005 - Final
#
#                                  Address Point  \
# 0            517 Albert Street, EAST MELBOURNE
# 1              178 Sims Street, WEST MELBOURNE
# 2  Alexandra Gardens, St Kilda Road, MELBOURNE
# 3              13 Harbour Esplanade, DOCKLANDS
# 4                            76 Canning Street
#
#                                  Artist Alternate Name Art Date Mel way Ref  \
# 0                       Robert Woodward            NaN     1981       2F_J1
# 1                               unknown            NaN     1941      2S_K11
# 2                      Raymond B. Ewers            NaN     1974       2F_J6
# 3                        Duncan Stemler            NaN     2005       2E_G8
# 4  Di Christensen and Bernice McPherson            NaN     1995       2A_E5
#
#    Respective Author                                       Structure  \
# 0  City Of Melbourne    Stainless-steel fountain on bluestone paving
# 1  City Of Melbourne                                 Basalt monument
# 2  City Of Melbourne  Bluestone drinking fountain with bronze plaque
# 3  City of Melbourne         Stainless-steel and aluminium sculpture
# 4  City Of Melbourne                          Stainless-steel panels
#
#                             Co-ordinates     Easting     Northing
# 0  (-37.8097706189194, 144.973483976518)  321609.360  5813356.512
# 1  (-37.8056957854241, 144.907291041632)  315771.745  5813680.208
# 2  (-37.8195705617737, 144.971824407255)  321486.867  5812265.881
# 3  (-37.8220182164578, 144.946871022845)  319296.292  5811946.283
# 4  (-37.7953526839703, 144.940687314302)  318686.757  5814893.278

# %% [markdown]
# ## 2. Clean up Raw Data

# %%
# Check missing values
df_raw_monuments.isnull().sum()
# Out:
# Asset Type             0
# Name                   0
# Xorg                   0
# Xsource                0
# Address Point          0
# Artist                 0
# Alternate Name       249
# Art Date               2
# Mel way Ref            0
# Respective Author      2
# Structure              0
# Co-ordinates           0
# Easting                0
# Northing               0
# dtype: int64

# %%
# Selet only usefull columns
useful_column = ['Asset Type', 'Name', 'Address Point', 'Artist', 'Art Date', 'Respective Author',
                 'Structure', 'Co-ordinates']
df_monuments = df_raw_monuments.loc[:,useful_column]

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#   Asset Type                                   Name  \
# 0   Fountain                         Coles Fountain
# 1        Art                  Port Phillip Monument
# 2   Monument  Black Swan Memorial Drinking Fountain
# 3        Art                               Blowhole
# 4        Art                            Bird Panels
#
#                                  Address Point  \
# 0            517 Albert Street, EAST MELBOURNE
# 1              178 Sims Street, WEST MELBOURNE
# 2  Alexandra Gardens, St Kilda Road, MELBOURNE
# 3              13 Harbour Esplanade, DOCKLANDS
# 4                            76 Canning Street
#
#                                  Artist Art Date  Respective Author  \
# 0                       Robert Woodward     1981  City Of Melbourne
# 1                               unknown     1941  City Of Melbourne
# 2                      Raymond B. Ewers     1974  City Of Melbourne
# 3                        Duncan Stemler     2005  City of Melbourne
# 4  Di Christensen and Bernice McPherson     1995  City Of Melbourne
#
#                                         Structure  \
# 0    Stainless-steel fountain on bluestone paving
# 1                                 Basalt monument
# 2  Bluestone drinking fountain with bronze plaque
# 3         Stainless-steel and aluminium sculpture
# 4                          Stainless-steel panels
#
#                             Co-ordinates
# 0  (-37.8097706189194, 144.973483976518)
# 1  (-37.8056957854241, 144.907291041632)
# 2  (-37.8195705617737, 144.971824407255)
# 3  (-37.8220182164578, 144.946871022845)
# 4  (-37.7953526839703, 144.940687314302)

# %%
# split 'Co-ordinates' -> 'latitude' 'longitude'
long_lati = df_monuments['Co-ordinates'].str.extract(r'\((.*)\)')[0].str.split(', ')
df_monuments.insert(7, 'latitude', long_lati.str[0])
df_monuments.insert(8, 'longitude', long_lati.str[1])

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#   Asset Type                                   Name  \
# 0   Fountain                         Coles Fountain
# 1        Art                  Port Phillip Monument
# 2   Monument  Black Swan Memorial Drinking Fountain
# 3        Art                               Blowhole
# 4        Art                            Bird Panels
#
#                                  Address Point  \
# 0            517 Albert Street, EAST MELBOURNE
# 1              178 Sims Street, WEST MELBOURNE
# 2  Alexandra Gardens, St Kilda Road, MELBOURNE
# 3              13 Harbour Esplanade, DOCKLANDS
# 4                            76 Canning Street
#
#                                  Artist Art Date  Respective Author  \
# 0                       Robert Woodward     1981  City Of Melbourne
# 1                               unknown     1941  City Of Melbourne
# 2                      Raymond B. Ewers     1974  City Of Melbourne
# 3                        Duncan Stemler     2005  City of Melbourne
# 4  Di Christensen and Bernice McPherson     1995  City Of Melbourne
#
#                                         Structure           latitude  \
# 0    Stainless-steel fountain on bluestone paving  -37.8097706189194
# 1                                 Basalt monument  -37.8056957854241
# 2  Bluestone drinking fountain with bronze plaque  -37.8195705617737
# 3         Stainless-steel and aluminium sculpture  -37.8220182164578
# 4                          Stainless-steel panels  -37.7953526839703
#
#           longitude                           Co-ordinates
# 0  144.973483976518  (-37.8097706189194, 144.973483976518)
# 1  144.907291041632  (-37.8056957854241, 144.907291041632)
# 2  144.971824407255  (-37.8195705617737, 144.971824407255)
# 3  144.946871022845  (-37.8220182164578, 144.946871022845)
# 4  144.940687314302  (-37.7953526839703, 144.940687314302)

# %%
# Check monument according to 'monument_class'
df_monuments['Asset Type'].value_counts()
# Out:
# Art         194
# Monument     47
# Fountain     20
# Name: Asset Type, dtype: int64

# %%
# Check monument according to 'monument_kind'
df_monuments['Respective Author'].value_counts()
# Out:
# City Of Melbourne               147
# City of Melbourne                59
# VicUrban                         52
# National Gallery of Victoria      1
# Name: Respective Author, dtype: int64

# %%
# Selet only usefull columns
useful_column = ['Asset Type', 'Name', 'Address Point', 'Artist', 'Art Date', 'Respective Author',
                 'Structure', 'latitude', 'longitude']
df_monuments = df_monuments.loc[:,useful_column]

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#   Asset Type                                   Name  \
# 0   Fountain                         Coles Fountain
# 1        Art                  Port Phillip Monument
# 2   Monument  Black Swan Memorial Drinking Fountain
# 3        Art                               Blowhole
# 4        Art                            Bird Panels
#
#                                  Address Point  \
# 0            517 Albert Street, EAST MELBOURNE
# 1              178 Sims Street, WEST MELBOURNE
# 2  Alexandra Gardens, St Kilda Road, MELBOURNE
# 3              13 Harbour Esplanade, DOCKLANDS
# 4                            76 Canning Street
#
#                                  Artist Art Date  Respective Author  \
# 0                       Robert Woodward     1981  City Of Melbourne
# 1                               unknown     1941  City Of Melbourne
# 2                      Raymond B. Ewers     1974  City Of Melbourne
# 3                        Duncan Stemler     2005  City of Melbourne
# 4  Di Christensen and Bernice McPherson     1995  City Of Melbourne
#
#                                         Structure           latitude  \
# 0    Stainless-steel fountain on bluestone paving  -37.8097706189194
# 1                                 Basalt monument  -37.8056957854241
# 2  Bluestone drinking fountain with bronze plaque  -37.8195705617737
# 3         Stainless-steel and aluminium sculpture  -37.8220182164578
# 4                          Stainless-steel panels  -37.7953526839703
#
#           longitude
# 0  144.973483976518
# 1  144.907291041632
# 2  144.971824407255
# 3  144.946871022845
# 4  144.940687314302

# %%
# Rename columns accordingly with format
df_monuments.rename(columns={'Asset Type':'type', 'Name':'name', 
                             'Address Point':'address', 'Artist':'artist', 
                             'Art Date':'date', 'Respective Author':'author', 
                             'Structure':'structure'}, inplace=True)

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#        type                                   name  \
# 0  Fountain                         Coles Fountain
# 1       Art                  Port Phillip Monument
# 2  Monument  Black Swan Memorial Drinking Fountain
# 3       Art                               Blowhole
# 4       Art                            Bird Panels
#
#                                        address  \
# 0            517 Albert Street, EAST MELBOURNE
# 1              178 Sims Street, WEST MELBOURNE
# 2  Alexandra Gardens, St Kilda Road, MELBOURNE
# 3              13 Harbour Esplanade, DOCKLANDS
# 4                            76 Canning Street
#
#                                  artist  date             author  \
# 0                       Robert Woodward  1981  City Of Melbourne
# 1                               unknown  1941  City Of Melbourne
# 2                      Raymond B. Ewers  1974  City Of Melbourne
# 3                        Duncan Stemler  2005  City of Melbourne
# 4  Di Christensen and Bernice McPherson  1995  City Of Melbourne
#
#                                         structure           latitude  \
# 0    Stainless-steel fountain on bluestone paving  -37.8097706189194
# 1                                 Basalt monument  -37.8056957854241
# 2  Bluestone drinking fountain with bronze plaque  -37.8195705617737
# 3         Stainless-steel and aluminium sculpture  -37.8220182164578
# 4                          Stainless-steel panels  -37.7953526839703
#
#           longitude
# 0  144.973483976518
# 1  144.907291041632
# 2  144.971824407255
# 3  144.946871022845
# 4  144.940687314302

# %%
# Include monument id (created)
df_monuments.insert(0, 'id', 'MONUM-')
df_monuments.insert(1, 'id_', range(1,len(df_monuments)+1))

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#        id  id_      type                                   name  \
# 0  MONUM-    1  Fountain                         Coles Fountain
# 1  MONUM-    2       Art                  Port Phillip Monument
# 2  MONUM-    3  Monument  Black Swan Memorial Drinking Fountain
# 3  MONUM-    4       Art                               Blowhole
# 4  MONUM-    5       Art                            Bird Panels
#
#                                        address  \
# 0            517 Albert Street, EAST MELBOURNE
# 1              178 Sims Street, WEST MELBOURNE
# 2  Alexandra Gardens, St Kilda Road, MELBOURNE
# 3              13 Harbour Esplanade, DOCKLANDS
# 4                            76 Canning Street
#
#                                  artist  date             author  \
# 0                       Robert Woodward  1981  City Of Melbourne
# 1                               unknown  1941  City Of Melbourne
# 2                      Raymond B. Ewers  1974  City Of Melbourne
# 3                        Duncan Stemler  2005  City of Melbourne
# 4  Di Christensen and Bernice McPherson  1995  City Of Melbourne
#
#                                         structure           latitude  \
# 0    Stainless-steel fountain on bluestone paving  -37.8097706189194
# 1                                 Basalt monument  -37.8056957854241
# 2  Bluestone drinking fountain with bronze plaque  -37.8195705617737
# 3         Stainless-steel and aluminium sculpture  -37.8220182164578
# 4                          Stainless-steel panels  -37.7953526839703
#
#           longitude
# 0  144.973483976518
# 1  144.907291041632
# 2  144.971824407255
# 3  144.946871022845
# 4  144.940687314302

# %%
# Include monument id (created)
df_monuments = df_monuments.astype({'id_':str})
df_monuments['id'] = df_monuments['id'] + df_monuments['id_']

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#         id id_      type                                   name  \
# 0  MONUM-1   1  Fountain                         Coles Fountain
# 1  MONUM-2   2       Art                  Port Phillip Monument
# 2  MONUM-3   3  Monument  Black Swan Memorial Drinking Fountain
# 3  MONUM-4   4       Art                               Blowhole
# 4  MONUM-5   5       Art                            Bird Panels
#
#                                        address  \
# 0            517 Albert Street, EAST MELBOURNE
# 1              178 Sims Street, WEST MELBOURNE
# 2  Alexandra Gardens, St Kilda Road, MELBOURNE
# 3              13 Harbour Esplanade, DOCKLANDS
# 4                            76 Canning Street
#
#                                  artist  date             author  \
# 0                       Robert Woodward  1981  City Of Melbourne
# 1                               unknown  1941  City Of Melbourne
# 2                      Raymond B. Ewers  1974  City Of Melbourne
# 3                        Duncan Stemler  2005  City of Melbourne
# 4  Di Christensen and Bernice McPherson  1995  City Of Melbourne
#
#                                         structure           latitude  \
# 0    Stainless-steel fountain on bluestone paving  -37.8097706189194
# 1                                 Basalt monument  -37.8056957854241
# 2  Bluestone drinking fountain with bronze plaque  -37.8195705617737
# 3         Stainless-steel and aluminium sculpture  -37.8220182164578
# 4                          Stainless-steel panels  -37.7953526839703
#
#           longitude
# 0  144.973483976518
# 1  144.907291041632
# 2  144.971824407255
# 3  144.946871022845
# 4  144.940687314302

# %%
# Selet only usefull columns
useful_column = ['id', 'type', 'name', 'address', 'artist', 
                 'date', 'author', 'structure', 'latitude','longitude']
df_monuments = df_monuments.loc[:,useful_column]

# %%
# Check whether the dataframe is as expected
df_monuments.head()
# Out:
#         id      type                                   name  \
# 0  MONUM-1  Fountain                         Coles Fountain
# 1  MONUM-2       Art                  Port Phillip Monument
# 2  MONUM-3  Monument  Black Swan Memorial Drinking Fountain
# 3  MONUM-4       Art                               Blowhole
# 4  MONUM-5       Art                            Bird Panels
#
#                                        address  \
# 0            517 Albert Street, EAST MELBOURNE
# 1              178 Sims Street, WEST MELBOURNE
# 2  Alexandra Gardens, St Kilda Road, MELBOURNE
# 3              13 Harbour Esplanade, DOCKLANDS
# 4                            76 Canning Street
#
#                                  artist  date             author  \
# 0                       Robert Woodward  1981  City Of Melbourne
# 1                               unknown  1941  City Of Melbourne
# 2                      Raymond B. Ewers  1974  City Of Melbourne
# 3                        Duncan Stemler  2005  City of Melbourne
# 4  Di Christensen and Bernice McPherson  1995  City Of Melbourne
#
#                                         structure           latitude  \
# 0    Stainless-steel fountain on bluestone paving  -37.8097706189194
# 1                                 Basalt monument  -37.8056957854241
# 2  Bluestone drinking fountain with bronze plaque  -37.8195705617737
# 3         Stainless-steel and aluminium sculpture  -37.8220182164578
# 4                          Stainless-steel panels  -37.7953526839703
#
#           longitude
# 0  144.973483976518
# 1  144.907291041632
# 2  144.971824407255
# 3  144.946871022845
# 4  144.940687314302

# %% [markdown]
# ## 3. Export Clean Data to a CSV file

# %%
# Export full version
df_monuments.to_csv('Output\Monuments\OK_Public_Monuments_2_Melbourne_V2.csv', index=False)
